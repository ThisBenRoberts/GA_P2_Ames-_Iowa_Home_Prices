# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
df_train = pd.read_csv('../datasets/cleaned_traindata_to_visualize.csv',keep_default_na=False)

# %%
pd.options.display.max_columns = 999  # Allos us to display all columns
df_train.columns = df_train.columns.str.lower() # column names to lower case

# %%
df_train.shape  # The differnece in # of columns should be neighborhood columns
# Out:
# (2051, 81)

# %% [markdown]
# With no Nulls, and no object (string) data, we can look at distributions, correlations to the target, and outliers.
# ### First, we're going to look at the correlations to saleprice.
# There is a lot of data here, and a limited amount of time, so we want to
# focus our efforts on the data points that we're most likely to include in
# any potention models.

# %%
df_train.corr()[['saleprice']].sort_values(['saleprice'], 
                                           ascending=False
                                          ).head(10)                # gives you everything corelated to apps
# Out:
#                saleprice
# saleprice       1.000000
# overall qual    0.800207
# gr liv area     0.697038
# garage area     0.649897
# garage cars     0.647781
# total bsmt sf   0.629303
# 1st flr sf      0.618486
# bsmt qual       0.612188
# year built      0.571849
# garage finish   0.557839

# %% [markdown]
# This is going to be a SUPER long list with over 170 features to consider, and strong neagtive and positive correlations to consider.
# To make this task easier, we're going to find the absolute values of our correlations, and then sort highest to lowest.
# We don't care if the correlation is positive or negative, we really just care about how close it is to 1.

# %%
corrs = df_train.corr()[['saleprice']].sort_values(['saleprice'], ascending=True)  #.index.tolist() 
# gives you every feature and its corelation to salesprice in terms of absolute value, both positive and negative
corrs.rename(columns={'saleprice':'corr_1'},inplace=True)
# calling the column corr_1 because we're going to try to deal with outliers and then retake the correlation 

corrs#.head(11)
#with help from https://www.marsja.se/renaming-columns-in-pandas-dataframe/#:~:text=So%20how%20do%20you%20change,columns%20%3D%20list_of_new_names%20.
# Out:
#                    corr_1
# pid             -0.255052
# fence           -0.159060
# enclosed porch  -0.135656
# kitchen abvgr   -0.125444
# overall cond    -0.097019
# ms subclass     -0.087335
# id              -0.051398
# misc feature    -0.048331
# bsmt half bath  -0.045290
# low qual fin sf -0.041594
# yr sold         -0.015203
# misc val        -0.007375
# bsmtfin type 2   0.014070
# bsmtfin sf 2     0.016432
# pool area        0.023106
# pool qc          0.029275
# mo sold          0.032735
# 3ssn porch       0.048732
# screen porch     0.134581
# bedroom abvgr    0.137067
# bsmt unf sf      0.190861
# bsmt cond        0.225075
# electrical       0.247842
# 2nd flr sf       0.248452
# garage yr blt    0.258645
# garage cond      0.265021
# half bath        0.283001
# bsmt full bath   0.283332
# garage qual      0.285281
# lot area         0.296566
# mas vnr type     0.312910
# lot frontage     0.319524
# wood deck sf     0.326490
# open porch sf    0.333476
# bsmtfin type 1   0.350362
# bsmtfin sf 1     0.423856
# bsmt exposure    0.424863
# garage type      0.427721
# fireplaces       0.471093
# mas vnr area     0.503579
# totrms abvgrd    0.504014
# full bath        0.537969
# fireplace qu     0.538925
# year remod/add   0.550370
# garage finish    0.557839
# year built       0.571849
# bsmt qual        0.612188
# 1st flr sf       0.618486
# total bsmt sf    0.629303
# garage cars      0.647781
# garage area      0.649897
# gr liv area      0.697038
# overall qual     0.800207
# saleprice        1.000000

# %% [markdown]
# ### Next, we're just going to plot those correlations and look for potential outliers

# %%
for feature in corrs.iterrows():
    #print(feature[0])
    #sns.jointplot(data=df_train, x="saleprice", y=feature[0], kind="reg", color='r')
    p = sns.jointplot(data=df_train, x="saleprice", y=feature[0], kind='reg', 
              line_kws={"color": "red"});
    p.fig.suptitle(feature[0])

# with help from 
# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas
# https://stackoverflow.com/questions/48145924/different-colors-for-points-and-line-in-seaborn-regplot
# Out:
# C:\Users\benro\anaconda3\lib\site-packages\seaborn\axisgrid.py:1670: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f = plt.figure(figsize=(height, height))

# %%
def find_outliers(col):
    q1 = np.percentile(df_train[col], 25)  # Find the first quartile
    q3 = np.percentile(df_train[col], 75)  # Find the third quartile
    iqr = q3 - q1                          # Calculate the IQR
             # The normal lower limit is Q1 – (1.5 * IQR)
             # THe normal upper limit as Q3 + (1.5 * IQR)
    lowerbound = q1 - 1.5 * iqr            # lower bound 
    upperbound = q3 + 1.5 * iqr            # Upper bound 
    
    return f'For {col}: below {lowerbound} or above {upperbound} is an outlier.'

for feature in corrs.head(10).iterrows():
    print(find_outliers(feature[0]))
# Out:
# For pid: below -39624770.0 or above 1475262990.0 is an outlier.
# For fence: below 0.0 or above 0.0 is an outlier.
# For enclosed porch: below 0.0 or above 0.0 is an outlier.
# For kitchen abvgr: below 1.0 or above 1.0 is an outlier.
# For overall cond: below 3.5 or above 7.5 is an outlier.
# For ms subclass: below -55.0 or above 145.0 is an outlier.
# For id: below -1413.25 or above 4364.75 is an outlier.
# For misc feature: below 0.0 or above 0.0 is an outlier.
# For bsmt half bath: below 0.0 or above 0.0 is an outlier.
# For low qual fin sf: below 0.0 or above 0.0 is an outlier.

# %%
for col in df_train.select_dtypes(include=np.number):
    df_train.hist(column=col)
    plt.xlabel(col)
    plt.ylabel('Count');

#with help from https://pythonexamples.org/pandas-dataframe-select-columns-of-numeric-datatype/
# df.select_dtypes(include='number')
# Out:
# C:\Users\benro\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:218: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)

# %%
df_train.head()
# Out:
#    1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 0         725         754           0    NA              3      1Fam
# 1         913        1209           0    NA              4      1Fam
# 2        1057           0           0    NA              3      1Fam
# 3         744         700           0    NA              3      1Fam
# 4         831         614           0    NA              3      1Fam
#
#    bsmt cond  bsmt exposure  bsmt full bath  bsmt half bath  bsmt qual  \
# 0          3              1             0.0             0.0          3
# 1          3              1             1.0             0.0          4
# 2          3              1             1.0             0.0          3
# 3          3              1             0.0             0.0          4
# 4          4              1             0.0             0.0          2
#
#    bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2  bsmtfin type 1  bsmtfin type 2  \
# 0        192.0         533.0           0.0               6               1
# 1        276.0         637.0           0.0               6               1
# 2        326.0         731.0           0.0               6               1
# 3        384.0           0.0           0.0               1               1
# 4        676.0           0.0           0.0               1               1
#
#   central air condition 1 condition 2  electrical  enclosed porch exter cond  \
# 0           Y        RRAe        Norm           5               0         TA
# 1           Y        Norm        Norm           5               0         TA
# 2           Y        Norm        Norm           5               0         Gd
# 3           Y        Norm        Norm           5               0         TA
# 4           Y        Norm        Norm           5               0         TA
#
#   exter qual exterior 1st exterior 2nd  fence  fireplace qu  fireplaces  \
# 0         Gd      HdBoard      Plywood      0             0           0
# 1         Gd      VinylSd      VinylSd      0             3           1
# 2         TA      VinylSd      VinylSd      0             0           0
# 3         TA      VinylSd      VinylSd      0             0           0
# 4         TA      Wd Sdng      Plywood      0             0           0
#
#   foundation  full bath functional  garage area  garage cars  garage cond  \
# 0     CBlock          2        Typ        475.0          2.0            3
# 1      PConc          2        Typ        559.0          2.0            3
# 2     CBlock          1        Typ        246.0          1.0            3
# 3      PConc          2        Typ        400.0          2.0            3
# 4      PConc          2        Typ        484.0          2.0            3
#
#    garage finish  garage qual  garage type  garage yr blt  gr liv area  \
# 0              2            3            5         1976.0         1479
# 1              2            3            5         1997.0         2122
# 2              1            3            1         1953.0         1057
# 3              3            3            3         2007.0         1444
# 4              1            3            1         1957.0         1445
#
#    half bath heating heating qc house style   id  kitchen abvgr kitchen qual  \
# 0          1    GasA         Ex      2Story  109              1           Gd
# 1          1    GasA         Ex      2Story  544              1           Gd
# 2          0    GasA         TA      1Story  153              1           Gd
# 3          1    GasA         Gd      2Story  318              1           TA
# 4          0    GasA         TA      1.5Fin  255              1           TA
#
#   land contour land slope  lot area lot config  lot frontage lot shape  \
# 0          Lvl        Gtl     13517    CulDSac     55.228571       IR1
# 1          Lvl        Gtl     11492    CulDSac     43.000000       IR1
# 2          Lvl        Gtl      7922     Inside     68.000000       Reg
# 3          Lvl        Gtl      9802     Inside     73.000000       Reg
# 4          Lvl        Gtl     14235     Inside     82.000000       IR1
#
#    low qual fin sf  ms subclass ms zoning  mas vnr area  mas vnr type  \
# 0                0           60        RL         289.0             3
# 1                0           60        RL         132.0             3
# 2                0           20        RL           0.0             0
# 3                0           60        RL           0.0             0
# 4                0           50        RL           0.0             0
#
#    misc feature  misc val  mo sold neighborhood  open porch sf  overall cond  \
# 0             0         0        3       Sawyer             44             8
# 1             0         0        4      SawyerW             74             5
# 2             0         0        1        NAmes             52             7
# 3             0         0        4       Timber              0             5
# 4             0         0        3      SawyerW             59             8
#
#    overall qual        pid paved drive  pool area  pool qc roof matl  \
# 0             6  533352170           Y          0        0   CompShg
# 1             7  531379050           Y          0        0   CompShg
# 2             5  535304180           Y          0        0   CompShg
# 3             5  916386060           Y          0        0   CompShg
# 4             6  906425045           N          0        0   CompShg
#
#   roof style sale type  saleprice  screen porch street  totrms abvgrd  \
# 0      Gable       WD      130500             0   Pave              6
# 1      Gable       WD      220000             0   Pave              8
# 2      Gable       WD      109000             0   Pave              5
# 3      Gable       WD      174000             0   Pave              7
# 4      Gable       WD      138500             0   Pave              6
#
#    total bsmt sf utilities  wood deck sf  year built  year remod/add  yr sold
# 0          725.0    AllPub             0        1976            2005     2010
# 1          913.0    AllPub             0        1996            1997     2009
# 2         1057.0    AllPub             0        1953            2007     2010
# 3          384.0    AllPub           100        2006            2007     2010
# 4          676.0    AllPub             0        1900            1993     2010

# %%
features = [
    'saleprice',
    'overall qual',
    'gr liv area',
#    'garage area',
#    'garage cars',
#    'total bsmt sf',
    '1st flr sf',
#    'bsmt qual',
    'year built',
    'garage finish',
    'year remod/add',
    'fireplaces',
    'lot area',
    '2nd flr sf',
    'fence'
]

# %%
hotfeatures = [
    'saleprice',
    'overall qual',
    'gr liv area',
    'garage area',
    'total bsmt sf',
    '1st flr sf',
    'bsmt qual',
    'year built',
]

# %%
coldfeatures = [
    'saleprice',
    'fence',
    'enclosed porch',
    'kitchen abvgr',
    'ms subclass',
    'misc feature',
    'bsmt half bath',
    'bsmtfin type 2'
]

# %%
# Total Correlations
plt.figure(figsize=(10,10))

sns.heatmap(df_train[features].corr()[['saleprice']].sort_values(by='saleprice', ascending=False), annot=True,
            cmap='coolwarm',
            vmin=-.1, 
            vmax=1) 

plt.suptitle('Correlations')
# Out:
# Text(0.5, 0.98, 'Correlations')

# %%
# Hot Correlations
plt.figure(figsize=(5,5))

sns.heatmap(df_train[hotfeatures].corr()[['saleprice']].sort_values(by='saleprice', ascending=False), annot=True,
            cmap='coolwarm',
            vmin=-.2, 
            vmax=1) 

plt.suptitle('Look for these')
# Out:
# Text(0.5, 0.98, 'Look for these')

# %%
# Cold Correlations
plt.figure(figsize=(5,5))

sns.heatmap(df_train[coldfeatures].corr()[['saleprice']].sort_values(by='saleprice', ascending=False), annot=True,
            cmap='coolwarm',
            vmin=-.2, 
            vmax=1) 

plt.suptitle('Ignore these')
# Out:
# Text(0.5, 0.98, 'Ignore these')

# %%
sns.heatmap(df_train.corr()[['saleprice']].sort_values('saleprice', ascending=False),
            annot=True,
            cmap='coolwarm',
            vmin=-1, 
            vmax=1)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df_train, x_vars=[
    'saleprice','overall qual','exter qual',
    'gr liv area','kitchen qual','garage area',
    'garage cars','1st flr sf','bsmt qual',
    'year built','year remod/add','fireplace qu',
    'full bath','totrms abvgrd','mas vnr area',
    'fireplaces','bsmtfin sf 1','open porch sf',
    'wood deck sf','lot frontage','lot area',
    'paved drive','garage qual','bsmt full bath','half bath'], y_vars=['saleprice'])   # specifying axis
# apps is out target so thats why we're looking at it

# %%
df_train.head()
# Out:
#    1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 0         725         754           0    NA              3      1Fam
# 1         913        1209           0    NA              4      1Fam
# 2        1057           0           0    NA              3      1Fam
# 3         744         700           0    NA              3      1Fam
# 4         831         614           0    NA              3      1Fam
#
#    bsmt cond  bsmt exposure  bsmt full bath  bsmt half bath  bsmt qual  \
# 0          3              1             0.0             0.0          3
# 1          3              1             1.0             0.0          4
# 2          3              1             1.0             0.0          3
# 3          3              1             0.0             0.0          4
# 4          4              1             0.0             0.0          2
#
#    bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2  bsmtfin type 1  bsmtfin type 2  \
# 0        192.0         533.0           0.0               6               1
# 1        276.0         637.0           0.0               6               1
# 2        326.0         731.0           0.0               6               1
# 3        384.0           0.0           0.0               1               1
# 4        676.0           0.0           0.0               1               1
#
#   central air condition 1 condition 2  electrical  enclosed porch exter cond  \
# 0           Y        RRAe        Norm           5               0         TA
# 1           Y        Norm        Norm           5               0         TA
# 2           Y        Norm        Norm           5               0         Gd
# 3           Y        Norm        Norm           5               0         TA
# 4           Y        Norm        Norm           5               0         TA
#
#   exter qual exterior 1st exterior 2nd  fence  fireplace qu  fireplaces  \
# 0         Gd      HdBoard      Plywood      0             0           0
# 1         Gd      VinylSd      VinylSd      0             3           1
# 2         TA      VinylSd      VinylSd      0             0           0
# 3         TA      VinylSd      VinylSd      0             0           0
# 4         TA      Wd Sdng      Plywood      0             0           0
#
#   foundation  full bath functional  garage area  garage cars  garage cond  \
# 0     CBlock          2        Typ        475.0          2.0            3
# 1      PConc          2        Typ        559.0          2.0            3
# 2     CBlock          1        Typ        246.0          1.0            3
# 3      PConc          2        Typ        400.0          2.0            3
# 4      PConc          2        Typ        484.0          2.0            3
#
#    garage finish  garage qual  garage type  garage yr blt  gr liv area  \
# 0              2            3            5         1976.0         1479
# 1              2            3            5         1997.0         2122
# 2              1            3            1         1953.0         1057
# 3              3            3            3         2007.0         1444
# 4              1            3            1         1957.0         1445
#
#    half bath heating heating qc house style   id  kitchen abvgr kitchen qual  \
# 0          1    GasA         Ex      2Story  109              1           Gd
# 1          1    GasA         Ex      2Story  544              1           Gd
# 2          0    GasA         TA      1Story  153              1           Gd
# 3          1    GasA         Gd      2Story  318              1           TA
# 4          0    GasA         TA      1.5Fin  255              1           TA
#
#   land contour land slope  lot area lot config  lot frontage lot shape  \
# 0          Lvl        Gtl     13517    CulDSac     55.228571       IR1
# 1          Lvl        Gtl     11492    CulDSac     43.000000       IR1
# 2          Lvl        Gtl      7922     Inside     68.000000       Reg
# 3          Lvl        Gtl      9802     Inside     73.000000       Reg
# 4          Lvl        Gtl     14235     Inside     82.000000       IR1
#
#    low qual fin sf  ms subclass ms zoning  mas vnr area  mas vnr type  \
# 0                0           60        RL         289.0             3
# 1                0           60        RL         132.0             3
# 2                0           20        RL           0.0             0
# 3                0           60        RL           0.0             0
# 4                0           50        RL           0.0             0
#
#    misc feature  misc val  mo sold neighborhood  open porch sf  overall cond  \
# 0             0         0        3       Sawyer             44             8
# 1             0         0        4      SawyerW             74             5
# 2             0         0        1        NAmes             52             7
# 3             0         0        4       Timber              0             5
# 4             0         0        3      SawyerW             59             8
#
#    overall qual        pid paved drive  pool area  pool qc roof matl  \
# 0             6  533352170           Y          0        0   CompShg
# 1             7  531379050           Y          0        0   CompShg
# 2             5  535304180           Y          0        0   CompShg
# 3             5  916386060           Y          0        0   CompShg
# 4             6  906425045           N          0        0   CompShg
#
#   roof style sale type  saleprice  screen porch street  totrms abvgrd  \
# 0      Gable       WD      130500             0   Pave              6
# 1      Gable       WD      220000             0   Pave              8
# 2      Gable       WD      109000             0   Pave              5
# 3      Gable       WD      174000             0   Pave              7
# 4      Gable       WD      138500             0   Pave              6
#
#    total bsmt sf utilities  wood deck sf  year built  year remod/add  yr sold
# 0          725.0    AllPub             0        1976            2005     2010
# 1          913.0    AllPub             0        1996            1997     2009
# 2         1057.0    AllPub             0        1953            2007     2010
# 3          384.0    AllPub           100        2006            2007     2010
# 4          676.0    AllPub             0        1900            1993     2010

# %%
# df_train['bsmt cond'] * df_train['bsmt exposure']
#     df_train['bsmt full bath']
#     df_train['bsmt qual']
#     df_train['bsmt unf sf']
#     df_train['bsmtfin sf 1']
#     df_train['bsmtfin sf 2']

# %%
# df_train['garage area * df_train['garage cars']
#     df_train['garage cond']
#     df_train['garage finish']
#     df_train['garage qual']

# %%
# df_train['land slope * df_train['lot shape']
#     df_train['lot area']
#     df_train['lot frontage']

# %%
df_corr_test = df_train
df_corr_test.dtypes
# Out:
# 1st flr sf         int64
# 2nd flr sf         int64
# 3ssn porch         int64
# alley             object
# bedroom abvgr      int64
#                    ...
# utilities         object
# wood deck sf       int64
# year built         int64
# year remod/add     int64
# yr sold            int64
# Length: 81, dtype: object

# %%
df_train['gr liv area']
df_train['bsmt qual']
df_train['overall qual']
df_train['exter qual']
df_train['garage area']
df_train['garage cars']
df_train['garage yr blt']
df_train['kitchen qual']
df_train['year built']
df_train['year remod/add']
df_train['yr sold']



df_train['gr liv area'] * df_train['bsmt qual']
df_train['overall qual'] * df_train['bsmt qual']
df_train['gr liv area'] * df_train['exter qual']
df_train['overall qual'] * df_train['exter qual']
df_train['overall qual'] * df_train['garage area']
df_train['overall qual'] * df_train['garage cars']
df_train['overall qual'] * df_train['garage yr blt']
df_train['kitchen qual'] * df_train['gr liv area'] 
df_train['overall qual'] * df_train['gr liv area'] 
df_train['overall qual'] * df_train['kitchen qual'] 
df_train['year built'] * df_train['overall qual']
df_train['year remod/add'] * df_train['overall qual']
df_train['yr sold'] * df_train['overall qual']
# Out:
# 0       12060
# 1       14063
# 2       10050
# 3       10050
# 4       12060
#         ...
# 2046    16064
# 2047     8036
# 2048    12054
# 2049     8036
# 2050    14070
# Length: 2051, dtype: int64

# %%
df_train['gr liv area']
df_train['bsmt qual']
df_train['overall qual']
df_train['exter qual']
df_train['garage area']
df_train['garage cars']
df_train['garage yr blt']
df_train['kitchen qual']
df_train['year built']
df_train['year remod/add']
df_train['yr sold']
# Out:
# 0       2010
# 1       2009
# 2       2010
# 3       2010
# 4       2010
#         ...
# 2046    2008
# 2047    2009
# 2048    2009
# 2049    2009
# 2050    2010
# Name: yr sold, Length: 2051, dtype: int64

# %%
df_train.agg([min,'mean',max])   # looking for potential outliers, maybe there is a better way?
#  with help from https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.agg.html
# Out:
#        1st flr sf   2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# min    334.000000     0.000000    0.000000  Grvl       0.000000      1Fam
# mean  1164.488055   329.329108    2.591419   NaN       2.843491       NaN
# max   5095.000000  1862.000000  508.000000  Pave       8.000000    TwnhsE
#
#       bsmt cond  bsmt exposure  bsmt full bath  bsmt half bath  bsmt qual  \
# min    0.000000       0.000000        0.000000        0.000000   0.000000
# mean   2.929303       1.628961        0.427109        0.063384   3.490005
# max    5.000000       4.000000        3.000000        2.000000   5.000000
#
#       bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2  bsmtfin type 1  bsmtfin type 2  \
# min      0.000000      0.000000      0.000000        0.000000          0.0000
# mean   567.451487    442.084837     47.935641        3.564603          1.2745
# max   2336.000000   5644.000000   1474.000000        6.000000          6.0000
#
#      central air condition 1 condition 2  electrical  enclosed porch  \
# min            N      Artery      Artery    1.000000        0.000000
# mean         NaN         NaN         NaN    4.885422       22.571916
# max            Y        RRNn        RRNn    5.000000      432.000000
#
#      exter cond exter qual exterior 1st exterior 2nd     fence  fireplace qu  \
# min          Ex         Ex      AsbShng      AsbShng  0.000000       0.00000
# mean        NaN        NaN          NaN          NaN  0.576792       1.76353
# max          TA         TA      WdShing      Wd Shng  4.000000       5.00000
#
#       fireplaces foundation  full bath functional  garage area  garage cars  \
# min     0.000000     BrkTil   0.000000       Maj1     0.000000     0.000000
# mean    0.590931        NaN   1.577279        NaN   473.440761     1.775719
# max     4.000000       Wood   4.000000        Typ  1418.000000     5.000000
#
#       garage cond  garage finish  garage qual  garage type  garage yr blt  \
# min      0.000000       0.000000     0.000000     0.000000       0.000000
# mean     2.810336       1.723062     2.803023     3.530473    1868.725987
# max      5.000000       3.000000     5.000000     6.000000    2207.000000
#
#       gr liv area  half bath heating heating qc house style           id  \
# min    334.000000   0.000000    GasA         Ex      1.5Fin     1.000000
# mean  1499.330083   0.371039     NaN        NaN         NaN  1474.033642
# max   5642.000000   2.000000    Wall         TA        SLvl  2930.000000
#
#       kitchen abvgr kitchen qual land contour land slope       lot area  \
# min        0.000000           Ex          Bnk        Gtl    1300.000000
# mean       1.042906          NaN          NaN        NaN   10065.208191
# max        3.000000           TA          Lvl        Sev  159000.000000
#
#      lot config  lot frontage lot shape  low qual fin sf  ms subclass  \
# min      Corner     21.000000       IR1         0.000000    20.000000
# mean        NaN     68.877439       NaN         5.512921    57.008776
# max      Inside    313.000000       Reg      1064.000000   190.000000
#
#      ms zoning  mas vnr area  mas vnr type  misc feature      misc val  \
# min    A (agr)      0.000000      0.000000      0.000000      0.000000
# mean       NaN     98.626524      1.028766      0.069722     51.574354
# max         RM   1600.000000      4.000000      5.000000  17000.000000
#
#         mo sold neighborhood  open porch sf  overall cond  overall qual  \
# min    1.000000      Blmngtn       0.000000      1.000000       1.00000
# mean   6.219893          NaN      47.556802      5.562165       6.11214
# max   12.000000      Veenker     547.000000      9.000000      10.00000
#
#                pid paved drive   pool area   pool qc roof matl roof style  \
# min   5.263011e+08           N    0.000000  0.000000   ClyTile       Flat
# mean  7.135900e+08         NaN    2.397855  0.015115       NaN        NaN
# max   9.241520e+08           Y  800.000000  5.000000   WdShngl       Shed
#
#      sale type      saleprice  screen porch street  totrms abvgrd  \
# min        COD   12789.000000      0.000000   Grvl       2.000000
# mean       NaN  181469.701609     16.511458    NaN       6.435885
# max        WD   611657.000000    490.000000   Pave      15.000000
#
#       total bsmt sf utilities  wood deck sf   year built  year remod/add  \
# min        0.000000    AllPub       0.00000  1872.000000     1950.000000
# mean    1057.471965       NaN      93.83374  1971.708922     1984.190151
# max     6110.000000    NoSewr    1424.00000  2010.000000     2010.000000
#
#           yr sold
# min   2006.000000
# mean  2007.775719
# max   2010.000000
