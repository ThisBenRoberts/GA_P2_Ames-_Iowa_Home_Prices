# %% [markdown]
# ## <span style='background :#3FBFBF' >*******************  IMPORTS *******************</span>

# %%
# Import 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score

df = pd.read_csv('./datasets/train.csv')
df_test = pd.read_csv('./datasets/test.csv')
# df_td = pd.DataFrame()

pd.options.display.max_columns = 999  # Allos us to display all columns
pd.options.display.max_rows = 999  # Allos us to display all columns

# %% [markdown]
# ## <span style='background :#3FBFBF' >*******************  DATA SETUP *******************</span>

# %%
df = df.reindex(sorted(df.columns),axis=1)  # puts cols in alpabetic order
df_test = df_test.reindex(sorted(df.columns),axis=1)  # puts cols in alpabetic order
df.columns = df.columns.str.lower() # column names to lower case
df_test.columns = df_test.columns.str.lower() # column names to lower case
df.head()
# Out:
#    1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 0         725         754           0   NaN              3      1Fam
# 1         913        1209           0   NaN              4      1Fam
# 2        1057           0           0   NaN              3      1Fam
# 3         744         700           0   NaN              3      1Fam
# 4         831         614           0   NaN              3      1Fam
#
#   bsmt cond bsmt exposure  bsmt full bath  bsmt half bath bsmt qual  \
# 0        TA            No             0.0             0.0        TA
# 1        TA            No             1.0             0.0        Gd
# 2        TA            No             1.0             0.0        TA
# 3        TA            No             0.0             0.0        Gd
# 4        Gd            No             0.0             0.0        Fa
#
#    bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 0        192.0         533.0           0.0            GLQ            Unf
# 1        276.0         637.0           0.0            GLQ            Unf
# 2        326.0         731.0           0.0            GLQ            Unf
# 3        384.0           0.0           0.0            Unf            Unf
# 4        676.0           0.0           0.0            Unf            Unf
#
#   central air condition 1 condition 2 electrical  enclosed porch exter cond  \
# 0           Y        RRAe        Norm      SBrkr               0         TA
# 1           Y        Norm        Norm      SBrkr               0         TA
# 2           Y        Norm        Norm      SBrkr               0         Gd
# 3           Y        Norm        Norm      SBrkr               0         TA
# 4           Y        Norm        Norm      SBrkr               0         TA
#
#   exter qual exterior 1st exterior 2nd fence fireplace qu  fireplaces  \
# 0         Gd      HdBoard      Plywood   NaN          NaN           0
# 1         Gd      VinylSd      VinylSd   NaN           TA           1
# 2         TA      VinylSd      VinylSd   NaN          NaN           0
# 3         TA      VinylSd      VinylSd   NaN          NaN           0
# 4         TA      Wd Sdng      Plywood   NaN          NaN           0
#
#   foundation  full bath functional  garage area  garage cars garage cond  \
# 0     CBlock          2        Typ        475.0          2.0          TA
# 1      PConc          2        Typ        559.0          2.0          TA
# 2     CBlock          1        Typ        246.0          1.0          TA
# 3      PConc          2        Typ        400.0          2.0          TA
# 4      PConc          2        Typ        484.0          2.0          TA
#
#   garage finish garage qual garage type  garage yr blt  gr liv area  \
# 0           RFn          TA      Attchd         1976.0         1479
# 1           RFn          TA      Attchd         1997.0         2122
# 2           Unf          TA      Detchd         1953.0         1057
# 3           Fin          TA     BuiltIn         2007.0         1444
# 4           Unf          TA      Detchd         1957.0         1445
#
#    half bath heating heating qc house style   id  kitchen abvgr kitchen qual  \
# 0          1    GasA         Ex      2Story  109              1           Gd
# 1          1    GasA         Ex      2Story  544              1           Gd
# 2          0    GasA         TA      1Story  153              1           Gd
# 3          1    GasA         Gd      2Story  318              1           TA
# 4          0    GasA         TA      1.5Fin  255              1           TA
#
#   land contour land slope  lot area lot config  lot frontage lot shape  \
# 0          Lvl        Gtl     13517    CulDSac           NaN       IR1
# 1          Lvl        Gtl     11492    CulDSac          43.0       IR1
# 2          Lvl        Gtl      7922     Inside          68.0       Reg
# 3          Lvl        Gtl      9802     Inside          73.0       Reg
# 4          Lvl        Gtl     14235     Inside          82.0       IR1
#
#    low qual fin sf  ms subclass ms zoning  mas vnr area mas vnr type  \
# 0                0           60        RL         289.0      BrkFace
# 1                0           60        RL         132.0      BrkFace
# 2                0           20        RL           0.0         None
# 3                0           60        RL           0.0         None
# 4                0           50        RL           0.0         None
#
#   misc feature  misc val  mo sold neighborhood  open porch sf  overall cond  \
# 0          NaN         0        3       Sawyer             44             8
# 1          NaN         0        4      SawyerW             74             5
# 2          NaN         0        1        NAmes             52             7
# 3          NaN         0        4       Timber              0             5
# 4          NaN         0        3      SawyerW             59             8
#
#    overall qual        pid paved drive  pool area pool qc roof matl  \
# 0             6  533352170           Y          0     NaN   CompShg
# 1             7  531379050           Y          0     NaN   CompShg
# 2             5  535304180           Y          0     NaN   CompShg
# 3             5  916386060           Y          0     NaN   CompShg
# 4             6  906425045           N          0     NaN   CompShg
#
#   roof style sale type  saleprice  screen porch street  totrms abvgrd  \
# 0      Gable       WD      130500             0   Pave              6
# 1      Gable       WD      220000             0   Pave              8
# 2      Gable       WD      109000             0   Pave              5
# 3      Gable       WD      174000             0   Pave              7
# 4      Gable       WD      138500             0   Pave              6
#
#    total bsmt sf utilities  wood deck sf  year built  year remod/add  yr sold
# 0          725.0    AllPub             0        1976            2005     2010
# 1          913.0    AllPub             0        1996            1997     2009
# 2         1057.0    AllPub             0        1953            2007     2010
# 3          384.0    AllPub           100        2006            2007     2010
# 4          676.0    AllPub             0        1900            1993     2010

# %%
df_test.head()
# Out:
#    1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 0         908        1020           0  Grvl              4    2fmCon
# 1        1967           0           0   NaN              6    Duplex
# 2         664         832           0   NaN              3      1Fam
# 3         968           0           0   NaN              2      1Fam
# 4        1394           0           0   NaN              3      1Fam
#
#   bsmt cond bsmt exposure  bsmt full bath  bsmt half bath bsmt qual  \
# 0        TA            No               0               0        Fa
# 1        TA            No               0               0        Gd
# 2        Gd            Av               1               0        Gd
# 3        TA            No               0               0        TA
# 4        TA            No               1               0        Gd
#
#    bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 0         1020             0             0            Unf            Unf
# 1         1967             0             0            Unf            Unf
# 2          100           554             0            GLQ            Unf
# 3          968             0             0            Unf            Unf
# 4          785           609             0            BLQ            Unf
#
#   central air condition 1 condition 2 electrical  enclosed porch exter cond  \
# 0           N        Norm        Norm      FuseP             112         Fa
# 1           Y        Norm        Norm      SBrkr               0         TA
# 2           Y        Norm        Norm      SBrkr               0         TA
# 3           Y        Norm        Norm      SBrkr             184         TA
# 4           Y        Norm        Norm      SBrkr               0         TA
#
#   exter qual exterior 1st exterior 2nd fence fireplace qu  fireplaces  \
# 0         TA      AsbShng      AsbShng   NaN          NaN           0
# 1         TA      Plywood      Plywood   NaN          NaN           0
# 2         Gd      VinylSd      VinylSd   NaN           Gd           1
# 3         Gd      Wd Sdng      Wd Sdng   NaN          NaN           0
# 4         TA      Plywood      Plywood   NaN           Gd           2
#
#   foundation  full bath functional  garage area  garage cars garage cond  \
# 0      Stone          2        Typ          440            1          Po
# 1     CBlock          2        Typ          580            2          TA
# 2      PConc          2        Typ          426            2          TA
# 3     CBlock          1        Typ          480            2          TA
# 4     CBlock          1        Typ          514            2          TA
#
#   garage finish garage qual garage type  garage yr blt  gr liv area  \
# 0           Unf          Po      Detchd         1910.0         1928
# 1           Fin          TA      Attchd         1977.0         1967
# 2           RFn          TA      Attchd         2006.0         1496
# 3           Unf          Fa      Detchd         1935.0          968
# 4           RFn          TA      Attchd         1963.0         1394
#
#    half bath heating heating qc house style    id  kitchen abvgr kitchen qual  \
# 0          0    GasA         Gd      2Story  2658              2           Fa
# 1          0    GasA         TA      1Story  2718              2           TA
# 2          1    GasA         Ex      2Story  2414              1           Gd
# 3          0    GasA         TA      1Story  1989              1           TA
# 4          1    GasA         Gd      1Story   625              1           TA
#
#   land contour land slope  lot area lot config  lot frontage lot shape  \
# 0          Lvl        Gtl      9142     Inside          69.0       Reg
# 1          Lvl        Gtl      9662     Inside           NaN       IR1
# 2          Lvl        Gtl     17104     Inside          58.0       IR1
# 3          Lvl        Gtl      8520     Inside          60.0       Reg
# 4          Lvl        Gtl      9500     Inside           NaN       IR1
#
#    low qual fin sf  ms subclass ms zoning  mas vnr area mas vnr type  \
# 0                0          190        RM           0.0         None
# 1                0           90        RL           0.0         None
# 2                0           60        RL           0.0         None
# 3                0           30        RM           0.0         None
# 4                0           20        RL         247.0      BrkFace
#
#   misc feature  misc val  mo sold neighborhood  open porch sf  overall cond  \
# 0          NaN         0        4      OldTown             60             8
# 1          NaN         0        8       Sawyer              0             4
# 2          NaN         0        9      Gilbert             24             5
# 3          NaN         0        7      OldTown              0             6
# 4          NaN         0        7        NAmes             76             5
#
#    overall qual        pid paved drive  pool area pool qc roof matl  \
# 0             6  902301120           Y          0     NaN   CompShg
# 1             5  905108090           Y          0     NaN   CompShg
# 2             7  528218130           Y          0     NaN   CompShg
# 3             5  902207150           N          0     NaN   CompShg
# 4             6  535105100           Y          0     NaN   CompShg
#
#   roof style sale type  saleprice  screen porch street  totrms abvgrd  \
# 0      Gable       WD         NaN             0   Pave              9
# 1      Gable       WD         NaN             0   Pave             10
# 2      Gable       New        NaN             0   Pave              7
# 3      Gable       WD         NaN             0   Pave              5
# 4      Gable       WD         NaN           185   Pave              6
#
#    total bsmt sf utilities  wood deck sf  year built  year remod/add  yr sold
# 0           1020    AllPub             0        1910            1950     2006
# 1           1967    AllPub           170        1977            1977     2006
# 2            654    AllPub           100        2006            2006     2006
# 3            968    AllPub             0        1923            2006     2007
# 4           1394    AllPub             0        1963            1963     2009

# %%
df.shape, df_test.shape   # Both sets have 81 columns (features)
# Out:
# ((2051, 81), (878, 81))

# %%
df.info() # Both sets have null values and object types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   1st flr sf       2051 non-null   int64
#  1   2nd flr sf       2051 non-null   int64
#  2   3ssn porch       2051 non-null   int64
#  3   alley            140 non-null    object
#  4   bedroom abvgr    2051 non-null   int64
#  5   bldg type        2051 non-null   object
#  6   bsmt cond        1996 non-null   object
#  7   bsmt exposure    1993 non-null   object
#  8   bsmt full bath   2049 non-null   float64
#  9   bsmt half bath   2049 non-null   float64
#  10  bsmt qual        1996 non-null   object
#  11  bsmt unf sf      2050 non-null   float64
#  12  bsmtfin sf 1     2050 non-null   float64
#  13  bsmtfin sf 2     2050 non-null   float64
#  14  bsmtfin type 1   1996 non-null   object
#  15  bsmtfin type 2   1995 non-null   object
#  16  central air      2051 non-null   object
#  17  condition 1      2051 non-null   object
#  18  condition 2      2051 non-null   object
#  19  electrical       2051 non-null   object
#  20  enclosed porch   2051 non-null   int64
#  21  exter cond       2051 non-null   object
#  22  exter qual       2051 non-null   object
#  23  exterior 1st     2051 non-null   object
#  24  exterior 2nd     2051 non-null   object
#  25  fence            400 non-null    object
#  26  fireplace qu     1051 non-null   object
#  27  fireplaces       2051 non-null   int64
#  28  foundation       2051 non-null   object
#  29  full bath        2051 non-null   int64
#  30  functional       2051 non-null   object
#  31  garage area      2050 non-null   float64
#  32  garage cars      2050 non-null   float64
#  33  garage cond      1937 non-null   object
#  34  garage finish    1937 non-null   object
#  35  garage qual      1937 non-null   object
#  36  garage type      1938 non-null   object
#  37  garage yr blt    1937 non-null   float64
#  38  gr liv area      2051 non-null   int64
#  39  half bath        2051 non-null   int64
#  40  heating          2051 non-null   object
#  41  heating qc       2051 non-null   object
#  42  house style      2051 non-null   object
#  43  id               2051 non-null   int64
#  44  kitchen abvgr    2051 non-null   int64
#  45  kitchen qual     2051 non-null   object
#  46  land contour     2051 non-null   object
#  47  land slope       2051 non-null   object
#  48  lot area         2051 non-null   int64
#  49  lot config       2051 non-null   object
#  50  lot frontage     1721 non-null   float64
#  51  lot shape        2051 non-null   object
#  52  low qual fin sf  2051 non-null   int64
#  53  ms subclass      2051 non-null   int64
#  54  ms zoning        2051 non-null   object
#  55  mas vnr area     2029 non-null   float64
#  56  mas vnr type     2029 non-null   object
#  57  misc feature     65 non-null     object
#  58  misc val         2051 non-null   int64
#  59  mo sold          2051 non-null   int64
#  60  neighborhood     2051 non-null   object
#  61  open porch sf    2051 non-null   int64
#  62  overall cond     2051 non-null   int64
#  63  overall qual     2051 non-null   int64
#  64  pid              2051 non-null   int64
#  65  paved drive      2051 non-null   object
#  66  pool area        2051 non-null   int64
#  67  pool qc          9 non-null      object
#  68  roof matl        2051 non-null   object
#  69  roof style       2051 non-null   object
#  70  sale type        2051 non-null   object
#  71  saleprice        2051 non-null   int64
#  72  screen porch     2051 non-null   int64
#  73  street           2051 non-null   object
#  74  totrms abvgrd    2051 non-null   int64
#  75  total bsmt sf    2050 non-null   float64
#  76  utilities        2051 non-null   object
#  77  wood deck sf     2051 non-null   int64
#  78  year built       2051 non-null   int64
#  79  year remod/add   2051 non-null   int64
#  80  yr sold          2051 non-null   int64
# dtypes: float64(11), int64(28), object(42)
# memory usage: 1.3+ MB

# %%
df_test.info()  # Both sets have null values and object types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878 entries, 0 to 877
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   1st flr sf       878 non-null    int64
#  1   2nd flr sf       878 non-null    int64
#  2   3ssn porch       878 non-null    int64
#  3   alley            58 non-null     object
#  4   bedroom abvgr    878 non-null    int64
#  5   bldg type        878 non-null    object
#  6   bsmt cond        853 non-null    object
#  7   bsmt exposure    853 non-null    object
#  8   bsmt full bath   878 non-null    int64
#  9   bsmt half bath   878 non-null    int64
#  10  bsmt qual        853 non-null    object
#  11  bsmt unf sf      878 non-null    int64
#  12  bsmtfin sf 1     878 non-null    int64
#  13  bsmtfin sf 2     878 non-null    int64
#  14  bsmtfin type 1   853 non-null    object
#  15  bsmtfin type 2   853 non-null    object
#  16  central air      878 non-null    object
#  17  condition 1      878 non-null    object
#  18  condition 2      878 non-null    object
#  19  electrical       877 non-null    object
#  20  enclosed porch   878 non-null    int64
#  21  exter cond       878 non-null    object
#  22  exter qual       878 non-null    object
#  23  exterior 1st     878 non-null    object
#  24  exterior 2nd     878 non-null    object
#  25  fence            172 non-null    object
#  26  fireplace qu     456 non-null    object
#  27  fireplaces       878 non-null    int64
#  28  foundation       878 non-null    object
#  29  full bath        878 non-null    int64
#  30  functional       878 non-null    object
#  31  garage area      878 non-null    int64
#  32  garage cars      878 non-null    int64
#  33  garage cond      833 non-null    object
#  34  garage finish    833 non-null    object
#  35  garage qual      833 non-null    object
#  36  garage type      834 non-null    object
#  37  garage yr blt    833 non-null    float64
#  38  gr liv area      878 non-null    int64
#  39  half bath        878 non-null    int64
#  40  heating          878 non-null    object
#  41  heating qc       878 non-null    object
#  42  house style      878 non-null    object
#  43  id               878 non-null    int64
#  44  kitchen abvgr    878 non-null    int64
#  45  kitchen qual     878 non-null    object
#  46  land contour     878 non-null    object
#  47  land slope       878 non-null    object
#  48  lot area         878 non-null    int64
#  49  lot config       878 non-null    object
#  50  lot frontage     718 non-null    float64
#  51  lot shape        878 non-null    object
#  52  low qual fin sf  878 non-null    int64
#  53  ms subclass      878 non-null    int64
#  54  ms zoning        878 non-null    object
#  55  mas vnr area     877 non-null    float64
#  56  mas vnr type     877 non-null    object
#  57  misc feature     41 non-null     object
#  58  misc val         878 non-null    int64
#  59  mo sold          878 non-null    int64
#  60  neighborhood     878 non-null    object
#  61  open porch sf    878 non-null    int64
#  62  overall cond     878 non-null    int64
#  63  overall qual     878 non-null    int64
#  64  pid              878 non-null    int64
#  65  paved drive      878 non-null    object
#  66  pool area        878 non-null    int64
#  67  pool qc          4 non-null      object
#  68  roof matl        878 non-null    object
#  69  roof style       878 non-null    object
#  70  sale type        878 non-null    object
#  71  saleprice        0 non-null      float64
#  72  screen porch     878 non-null    int64
#  73  street           878 non-null    object
#  74  totrms abvgrd    878 non-null    int64
#  75  total bsmt sf    878 non-null    int64
#  76  utilities        878 non-null    object
#  77  wood deck sf     878 non-null    int64
#  78  year built       878 non-null    int64
#  79  year remod/add   878 non-null    int64
#  80  yr sold          878 non-null    int64
# dtypes: float64(4), int64(35), object(42)
# memory usage: 555.7+ KB

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
df.describe(include=[np.number]).T  # Use .T to transpose and make it easier to read

# with help from https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html
# and https://stackoverflow.com/questions/55394854/how-to-change-the-format-of-describe-output

# I don't see any negative min numbers
# Looking at the different between Min 25% - 75% and Max for outliers...
# 1st flr sf
# bedroom abvgr
# bsmt full bath
# bsmt unf sf
# bsmtfin sf 1
# bsmtfin sf 2 - what is this?
# fireplaces
# garage area	
# gr liv area
# lot area
# lot frontage
# low qual fin sf - weird?
# mas vnr area - weird?
# open porch sf
# saleprice
# totrms abvgrd
# wood deck sf
# Out:
#                      count            mean             std             min  \
# 1st flr sf      2051.00000      1164.48805       396.44692       334.00000
# 2nd flr sf      2051.00000       329.32911       425.67105         0.00000
# 3ssn porch      2051.00000         2.59142        25.22961         0.00000
# bedroom abvgr   2051.00000         2.84349         0.82662         0.00000
# bsmt full bath  2049.00000         0.42753         0.52267         0.00000
# bsmt half bath  2049.00000         0.06345         0.25171         0.00000
# bsmt unf sf     2050.00000       567.72829       444.95479         0.00000
# bsmtfin sf 1    2050.00000       442.30049       461.20412         0.00000
# bsmtfin sf 2    2050.00000        47.95902       165.00090         0.00000
# enclosed porch  2051.00000        22.57192        59.84511         0.00000
# fireplaces      2051.00000         0.59093         0.63852         0.00000
# full bath       2051.00000         1.57728         0.54928         0.00000
# garage area     2050.00000       473.67171       215.93456         0.00000
# garage cars     2050.00000         1.77659         0.76454         0.00000
# garage yr blt   1937.00000      1978.70780        25.44109      1895.00000
# gr liv area     2051.00000      1499.33008       500.44783       334.00000
# half bath       2051.00000         0.37104         0.50104         0.00000
# id              2051.00000      1474.03364       843.98084         1.00000
# kitchen abvgr   2051.00000         1.04291         0.20979         0.00000
# lot area        2051.00000     10065.20819      6742.48891      1300.00000
# lot frontage    1721.00000        69.05520        23.26065        21.00000
# low qual fin sf 2051.00000         5.51292        51.06887         0.00000
# ms subclass     2051.00000        57.00878        42.82422        20.00000
# mas vnr area    2029.00000        99.69591       174.96313         0.00000
# misc val        2051.00000        51.57435       573.39399         0.00000
# mo sold         2051.00000         6.21989         2.74474         1.00000
# open porch sf   2051.00000        47.55680        66.74724         0.00000
# overall cond    2051.00000         5.56216         1.10450         1.00000
# overall qual    2051.00000         6.11214         1.42627         1.00000
# pid             2051.00000 713590006.09166 188691837.88533 526301100.00000
# pool area       2051.00000         2.39785        37.78257         0.00000
# saleprice       2051.00000    181469.70161     79258.65935     12789.00000
# screen porch    2051.00000        16.51146        57.37420         0.00000
# totrms abvgrd   2051.00000         6.43588         1.56022         2.00000
# total bsmt sf   2050.00000      1057.98780       449.41070         0.00000
# wood deck sf    2051.00000        93.83374       128.54942         0.00000
# year built      2051.00000      1971.70892        30.17789      1872.00000
# year remod/add  2051.00000      1984.19015        21.03625      1950.00000
# yr sold         2051.00000      2007.77572         1.31201      2006.00000
#
#                             25%             50%             75%  \
# 1st flr sf            879.50000      1093.00000      1405.00000
# 2nd flr sf              0.00000         0.00000       692.50000
# 3ssn porch              0.00000         0.00000         0.00000
# bedroom abvgr           2.00000         3.00000         3.00000
# bsmt full bath          0.00000         0.00000         1.00000
# bsmt half bath          0.00000         0.00000         0.00000
# bsmt unf sf           220.00000       474.50000       811.00000
# bsmtfin sf 1            0.00000       368.00000       733.75000
# bsmtfin sf 2            0.00000         0.00000         0.00000
# enclosed porch          0.00000         0.00000         0.00000
# fireplaces              0.00000         1.00000         1.00000
# full bath               1.00000         2.00000         2.00000
# garage area           319.00000       480.00000       576.00000
# garage cars             1.00000         2.00000         2.00000
# garage yr blt        1961.00000      1980.00000      2002.00000
# gr liv area          1129.00000      1444.00000      1728.50000
# half bath               0.00000         0.00000         1.00000
# id                    753.50000      1486.00000      2198.00000
# kitchen abvgr           1.00000         1.00000         1.00000
# lot area             7500.00000      9430.00000     11513.50000
# lot frontage           58.00000        68.00000        80.00000
# low qual fin sf         0.00000         0.00000         0.00000
# ms subclass            20.00000        50.00000        70.00000
# mas vnr area            0.00000         0.00000       161.00000
# misc val                0.00000         0.00000         0.00000
# mo sold                 4.00000         6.00000         8.00000
# open porch sf           0.00000        27.00000        70.00000
# overall cond            5.00000         5.00000         6.00000
# overall qual            5.00000         6.00000         7.00000
# pid             528458140.00000 535453200.00000 907180080.00000
# pool area               0.00000         0.00000         0.00000
# saleprice          129825.00000    162500.00000    214000.00000
# screen porch            0.00000         0.00000         0.00000
# totrms abvgrd           5.00000         6.00000         7.00000
# total bsmt sf         793.00000       994.50000      1318.75000
# wood deck sf            0.00000         0.00000       168.00000
# year built           1953.50000      1974.00000      2001.00000
# year remod/add       1964.50000      1993.00000      2004.00000
# yr sold              2007.00000      2008.00000      2009.00000
#
#                             max
# 1st flr sf           5095.00000
# 2nd flr sf           1862.00000
# 3ssn porch            508.00000
# bedroom abvgr           8.00000
# bsmt full bath          3.00000
# bsmt half bath          2.00000
# bsmt unf sf          2336.00000
# bsmtfin sf 1         5644.00000
# bsmtfin sf 2         1474.00000
# enclosed porch        432.00000
# fireplaces              4.00000
# full bath               4.00000
# garage area          1418.00000
# garage cars             5.00000
# garage yr blt        2207.00000
# gr liv area          5642.00000
# half bath               2.00000
# id                   2930.00000
# kitchen abvgr           3.00000
# lot area           159000.00000
# lot frontage          313.00000
# low qual fin sf      1064.00000
# ms subclass           190.00000
# mas vnr area         1600.00000
# misc val            17000.00000
# mo sold                12.00000
# open porch sf         547.00000
# overall cond            9.00000
# overall qual           10.00000
# pid             924152030.00000
# pool area             800.00000
# saleprice          611657.00000
# screen porch          490.00000
# totrms abvgrd          15.00000
# total bsmt sf        6110.00000
# wood deck sf         1424.00000
# year built           2010.00000
# year remod/add       2010.00000
# yr sold              2010.00000

# %%
df_test.describe(include=[np.number]).T
# Out:
#                     count            mean             std             min  \
# 1st flr sf      878.00000      1145.78702       375.26411       407.00000
# 2nd flr sf      878.00000       348.39863       432.98557         0.00000
# 3ssn porch      878.00000         2.59795        24.96248         0.00000
# bedroom abvgr   878.00000         2.87927         0.83071         0.00000
# bsmt full bath  878.00000         0.43964         0.52995         0.00000
# bsmt half bath  878.00000         0.05581         0.22968         0.00000
# bsmt unf sf     878.00000       539.13326       426.17216         0.00000
# bsmtfin sf 1    878.00000       441.32802       438.45733         0.00000
# bsmtfin sf 2    878.00000        53.89636       178.63236         0.00000
# enclosed porch  878.00000        24.06492        73.24946         0.00000
# fireplaces      878.00000         0.61845         0.66957         0.00000
# full bath       878.00000         1.53986         0.55906         0.00000
# garage area     878.00000       470.36219       212.73407         0.00000
# garage cars     878.00000         1.74260         0.75039         0.00000
# garage yr blt   833.00000      1976.75990        25.68976      1900.00000
# gr liv area     878.00000      1496.91458       506.46897       407.00000
# half bath       878.00000         0.39863         0.50593         0.00000
# id              878.00000      1444.74943       850.83826         2.00000
# kitchen abvgr   878.00000         1.04784         0.22397         0.00000
# lot area        878.00000     10307.03303     10002.67460      1477.00000
# lot frontage    718.00000        69.54596        23.53394        21.00000
# low qual fin sf 878.00000         2.72893        32.57255         0.00000
# ms subclass     878.00000        58.26879        42.23541        20.00000
# mas vnr area    877.00000       106.23603       187.15891         0.00000
# misc val        878.00000        48.49886       550.16932         0.00000
# mo sold         878.00000         6.20273         2.64250         1.00000
# open porch sf   878.00000        47.07062        68.18094         0.00000
# overall cond    878.00000         5.56606         1.12890         1.00000
# overall qual    878.00000         6.05011         1.36906         2.00000
# pid             878.00000 716286696.44419 188910255.63158 526302110.00000
# pool area       878.00000         1.88497        29.91667         0.00000
# saleprice         0.00000             NaN             NaN             NaN
# screen porch    878.00000        14.83030        53.00379         0.00000
# totrms abvgrd   878.00000         6.45444         1.59663         3.00000
# total bsmt sf   878.00000      1034.35763       413.44629         0.00000
# wood deck sf    878.00000        93.43052       121.18170         0.00000
# year built      878.00000      1970.49203        30.39589      1880.00000
# year remod/add  878.00000      1984.41800        20.45072      1950.00000
# yr sold         878.00000      2007.82574         1.32786      2006.00000
#
#                             25%             50%             75%  \
# 1st flr sf            864.00000      1063.00000      1358.00000
# 2nd flr sf              0.00000         0.00000       720.00000
# 3ssn porch              0.00000         0.00000         0.00000
# bedroom abvgr           2.00000         3.00000         3.00000
# bsmt full bath          0.00000         0.00000         1.00000
# bsmt half bath          0.00000         0.00000         0.00000
# bsmt unf sf           216.00000       452.00000       780.00000
# bsmtfin sf 1            0.00000       373.00000       734.75000
# bsmtfin sf 2            0.00000         0.00000         0.00000
# enclosed porch          0.00000         0.00000         0.00000
# fireplaces              0.00000         1.00000         1.00000
# full bath               1.00000         2.00000         2.00000
# garage area           322.50000       473.00000       576.00000
# garage cars             1.00000         2.00000         2.00000
# garage yr blt        1960.00000      1978.00000      2001.00000
# gr liv area          1114.00000      1436.00000      1779.00000
# half bath               0.00000         0.00000         1.00000
# id                    692.25000      1433.00000      2197.50000
# kitchen abvgr           1.00000         1.00000         1.00000
# lot area             7297.25000      9446.00000     11589.00000
# lot frontage           59.00000        68.00000        80.00000
# low qual fin sf         0.00000         0.00000         0.00000
# ms subclass            20.00000        50.00000        70.00000
# mas vnr area            0.00000         0.00000       172.00000
# misc val                0.00000         0.00000         0.00000
# mo sold                 5.00000         6.00000         8.00000
# open porch sf           0.00000        27.00000        69.75000
# overall cond            5.00000         5.00000         6.00000
# overall qual            5.00000         6.00000         7.00000
# pid             528484107.50000 535454155.00000 907190362.50000
# pool area               0.00000         0.00000         0.00000
# saleprice                   NaN             NaN             NaN
# screen porch            0.00000         0.00000         0.00000
# totrms abvgrd           5.00000         6.00000         7.00000
# total bsmt sf         789.00000       975.00000      1247.00000
# wood deck sf            0.00000         0.00000       170.75000
# year built           1954.00000      1972.00000      1999.75000
# year remod/add       1967.00000      1992.00000      2003.00000
# yr sold              2007.00000      2008.00000      2009.00000
#
#                              max
# 1st flr sf            2674.00000
# 2nd flr sf            2065.00000
# 3ssn porch             360.00000
# bedroom abvgr            6.00000
# bsmt full bath           2.00000
# bsmt half bath           1.00000
# bsmt unf sf           2046.00000
# bsmtfin sf 1          2288.00000
# bsmtfin sf 2          1526.00000
# enclosed porch        1012.00000
# fireplaces               3.00000
# full bath                4.00000
# garage area           1488.00000
# garage cars              4.00000
# garage yr blt         2010.00000
# gr liv area           4476.00000
# half bath                2.00000
# id                    2928.00000
# kitchen abvgr            3.00000
# lot area            215245.00000
# lot frontage           182.00000
# low qual fin sf        481.00000
# ms subclass            190.00000
# mas vnr area          1378.00000
# misc val             15500.00000
# mo sold                 12.00000
# open porch sf          742.00000
# overall cond             9.00000
# overall qual            10.00000
# pid             1007100110.00000
# pool area              555.00000
# saleprice                    NaN
# screen porch           576.00000
# totrms abvgrd           12.00000
# total bsmt sf         2630.00000
# wood deck sf           690.00000
# year built            2010.00000
# year remod/add        2010.00000
# yr sold               2010.00000

# %%
df.describe(include=[object])  # describes all of the object or string features
# Out:
#        alley bldg type bsmt cond bsmt exposure bsmt qual bsmtfin type 1  \
# count    140      2051      1996          1993      1996           1996
# unique     2         5         5             4         5              6
# top     Grvl      1Fam        TA            No        TA            GLQ
# freq      85      1700      1834          1339       887            615
#
#        bsmtfin type 2 central air condition 1 condition 2 electrical  \
# count            1995        2051        2051        2051       2051
# unique              6           2           9           8          5
# top               Unf           Y        Norm        Norm      SBrkr
# freq             1749        1910        1767        2025       1868
#
#        exter cond exter qual exterior 1st exterior 2nd  fence fireplace qu  \
# count        2051       2051         2051         2051    400         1051
# unique          5          4           15           15      4            5
# top            TA         TA      VinylSd      VinylSd  MnPrv           Gd
# freq         1778       1247          724          721    227          523
#
#        foundation functional garage cond garage finish garage qual  \
# count        2051       2051        1937          1937        1937
# unique          6          8           5             3           5
# top         PConc        Typ          TA           Unf          TA
# freq          926       1915        1868           849        1832
#
#        garage type heating heating qc house style kitchen qual land contour  \
# count         1938    2051       2051        2051         2051         2051
# unique           6       5          5           8            4            4
# top         Attchd    GasA         Ex      1Story           TA          Lvl
# freq          1213    2018       1065        1059         1047         1843
#
#        land slope lot config lot shape ms zoning mas vnr type misc feature  \
# count        2051       2051      2051      2051         2029           65
# unique          3          5         4         7            4            5
# top           Gtl     Inside       Reg        RL         None         Shed
# freq         1953       1503      1295      1598         1218           56
#
#        neighborhood paved drive pool qc roof matl roof style sale type street  \
# count          2051        2051       9      2051       2051      2051   2051
# unique           28           3       4         6          6         9      2
# top           NAmes           Y      Gd   CompShg      Gable       WD    Pave
# freq            310        1861       4      2025       1619      1781   2044
#
#        utilities
# count       2051
# unique         3
# top       AllPub
# freq        2049

# %%
df_test.describe(include=[object])  # describes all of the object or string features
# Out:
#        alley bldg type bsmt cond bsmt exposure bsmt qual bsmtfin type 1  \
# count     58       878       853           853       853            853
# unique     2         5         3             4         5              6
# top     Grvl      1Fam        TA            No        TA            Unf
# freq      35       724       781           567       396            248
#
#        bsmtfin type 2 central air condition 1 condition 2 electrical  \
# count             853         878         878         878        877
# unique              6           2           9           3          4
# top               Unf           Y        Norm        Norm      SBrkr
# freq              749         823         755         875        813
#
#        exter cond exter qual exterior 1st exterior 2nd  fence fireplace qu  \
# count         878        878          878          878    172          456
# unique          5          4           13           16      4            5
# top            TA         TA      VinylSd      VinylSd  MnPrv           Gd
# freq          770        552          302          294    103          220
#
#        foundation functional garage cond garage finish garage qual  \
# count         878        878         833           833         833
# unique          6          6           5             3           4
# top         PConc        Typ          TA           Unf          TA
# freq          383        812         796           382         782
#
#        garage type heating heating qc house style kitchen qual land contour  \
# count          834     878        878         878          878          878
# unique           6       4          4           8            5            4
# top         Attchd    GasA         Ex      1Story           TA          Lvl
# freq           518     866        429         422          447          790
#
#        land slope lot config lot shape ms zoning mas vnr type misc feature  \
# count         878        878       878       878          877           41
# unique          3          5         4         6            5            3
# top           Gtl     Inside       Reg        RL         None         Shed
# freq          835        636       564       674          534           39
#
#        neighborhood paved drive pool qc roof matl roof style sale type street  \
# count           878         878       4       878        878       878    878
# unique           26           3       2         6          6        10      2
# top           NAmes           Y      Ex   CompShg      Gable       WD    Pave
# freq            133         790       3       861        702       755    873
#
#        utilities
# count        878
# unique         2
# top       AllPub
# freq         877

# %% [markdown]
# # <span style='background :#3FBFBF' >*******************  LET'S FIX ALL OF THE NaN's *******************</span>

# %%
df.isnull().sum()   
# Look at the columns with fewer Nan's first. 
# A lot of the basement features are NaN in similar amounts.  
# The same for garages.
# Out:
# 1st flr sf            0
# 2nd flr sf            0
# 3ssn porch            0
# alley              1911
# bedroom abvgr         0
# bldg type             0
# bsmt cond            55
# bsmt exposure        58
# bsmt full bath        2
# bsmt half bath        2
# bsmt qual            55
# bsmt unf sf           1
# bsmtfin sf 1          1
# bsmtfin sf 2          1
# bsmtfin type 1       55
# bsmtfin type 2       56
# central air           0
# condition 1           0
# condition 2           0
# electrical            0
# enclosed porch        0
# exter cond            0
# exter qual            0
# exterior 1st          0
# exterior 2nd          0
# fence              1651
# fireplace qu       1000
# fireplaces            0
# foundation            0
# full bath             0
# functional            0
# garage area           1
# garage cars           1
# garage cond         114
# garage finish       114
# garage qual         114
# garage type         113
# garage yr blt       114
# gr liv area           0
# half bath             0
# heating               0
# heating qc            0
# house style           0
# id                    0
# kitchen abvgr         0
# kitchen qual          0
# land contour          0
# land slope            0
# lot area              0
# lot config            0
# lot frontage        330
# lot shape             0
# low qual fin sf       0
# ms subclass           0
# ms zoning             0
# mas vnr area         22
# mas vnr type         22
# misc feature       1986
# misc val              0
# mo sold               0
# neighborhood          0
# open porch sf         0
# overall cond          0
# overall qual          0
# pid                   0
# paved drive           0
# pool area             0
# pool qc            2042
# roof matl             0
# roof style            0
# sale type             0
# saleprice             0
# screen porch          0
# street                0
# totrms abvgrd         0
# total bsmt sf         1
# utilities             0
# wood deck sf          0
# year built            0
# year remod/add        0
# yr sold               0
# dtype: int64

# %%
df[df['bsmt full bath'].isnull()].head() 


# It looks like 616 is a slab foundation, and 1327 is a poured concrete foundation.  
# Thay may not have basements at all, so the NaN values might need to be 0
# Documentation says that Bsmt Qual should be NA if there is no basement
# same for bsmt cond, Bsmt Exposure, BsmtFin Type 1, BsmtFinType 2
# Out:
#       1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 616         3820           0           0   NaN              5      1Fam
# 1327         896           0           0   NaN              2      1Fam
#
#      bsmt cond bsmt exposure  bsmt full bath  bsmt half bath bsmt qual  \
# 616        NaN           NaN             NaN             NaN       NaN
# 1327       NaN           NaN             NaN             NaN       NaN
#
#       bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 616       0.00000       0.00000       0.00000            NaN            NaN
# 1327          NaN           NaN           NaN            NaN            NaN
#
#      central air condition 1 condition 2 electrical  enclosed porch  \
# 616            Y        Norm        Norm      SBrkr               0
# 1327           Y       Feedr        Norm      FuseA               0
#
#      exter cond exter qual exterior 1st exterior 2nd  fence fireplace qu  \
# 616          TA         TA      Plywood      Plywood    NaN           Gd
# 1327         TA         TA      MetalSd       CBlock  MnPrv          NaN
#
#       fireplaces foundation  full bath functional  garage area  garage cars  \
# 616            2       Slab          3        Typ    624.00000      2.00000
# 1327           0      PConc          1        Typ    280.00000      1.00000
#
#      garage cond garage finish garage qual garage type  garage yr blt  \
# 616           TA           Unf          TA      Attchd     1959.00000
# 1327          TA           Unf          TA      Detchd     1946.00000
#
#       gr liv area  half bath heating heating qc house style    id  \
# 616          3820          1    GasA         TA      1Story  1498
# 1327          896          0    GasA         TA      1Story  1342
#
#       kitchen abvgr kitchen qual land contour land slope  lot area lot config  \
# 616               1           Ex          Lvl        Gtl     47007     Inside
# 1327              1           TA          Lvl        Gtl      5940        FR3
#
#       lot frontage lot shape  low qual fin sf  ms subclass ms zoning  \
# 616      123.00000       IR1                0           20        RL
# 1327      99.00000       IR1                0           20        RM
#
#       mas vnr area mas vnr type misc feature  misc val  mo sold neighborhood  \
# 616        0.00000         None          NaN         0        7      Edwards
# 1327       0.00000         None          NaN         0        4      BrkSide
#
#       open porch sf  overall cond  overall qual        pid paved drive  \
# 616             372             7             5  908154080           Y
# 1327              0             7             4  903230120           Y
#
#       pool area pool qc roof matl roof style sale type  saleprice  \
# 616           0     NaN   CompShg      Gable       WD      284700
# 1327          0     NaN   CompShg      Gable     ConLD      79000
#
#       screen porch street  totrms abvgrd  total bsmt sf utilities  \
# 616              0   Pave             11        0.00000    AllPub
# 1327             0   Pave              4            NaN    AllPub
#
#       wood deck sf  year built  year remod/add  yr sold
# 616              0        1959            1996     2008
# 1327             0        1946            1950     2008

# %%
df['bsmt qual'].value_counts()
# it looks like the NA is missing
# Out:
# TA    887
# Gd    864
# Ex    184
# Fa     60
# Po      1
# Name: bsmt qual, dtype: int64

# %%
df['bsmt qual'].isnull().value_counts()   # 55 NaN's to replace with 'NA'
# Out:
# False    1996
# True       55
# Name: bsmt qual, dtype: int64

# %%
df['bsmt qual'] = df['bsmt qual'].fillna('NA')
df_test['bsmt qual'] = df_test['bsmt qual'].fillna('NA')

df['bsmt qual'].value_counts()
# Out:
# TA    887
# Gd    864
# Ex    184
# Fa     60
# NA     55
# Po      1
# Name: bsmt qual, dtype: int64

# %%
basement_to_fix = ['bsmt cond','bsmt exposure','bsmtfin type 1','bsmtfin type 2']  # all of these need to be fixed too

for bsmt in basement_to_fix:
    df[bsmt] = df[bsmt].fillna('NA')   # Replace NaN with 'NA' for all of the columns above

# %%
   
for bsmt in basement_to_fix:
    df_test [bsmt] = df_test [bsmt].fillna('NA')   # Replace NaN with 'NA' for all of the columns above

# %%
df[df['bsmt full bath'].isnull()].head()  
# bsmt full bath, bsmt half bath, bsmt unf sf, bsmtfin sf 1, bsmtfin sf 2 
# could all be 0 since there is no basement 
# **IF** there really is no basement
# Out:
#       1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 616         3820           0           0   NaN              5      1Fam
# 1327         896           0           0   NaN              2      1Fam
#
#      bsmt cond bsmt exposure  bsmt full bath  bsmt half bath bsmt qual  \
# 616         NA            NA             NaN             NaN        NA
# 1327        NA            NA             NaN             NaN        NA
#
#       bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 616       0.00000       0.00000       0.00000             NA             NA
# 1327          NaN           NaN           NaN             NA             NA
#
#      central air condition 1 condition 2 electrical  enclosed porch  \
# 616            Y        Norm        Norm      SBrkr               0
# 1327           Y       Feedr        Norm      FuseA               0
#
#      exter cond exter qual exterior 1st exterior 2nd  fence fireplace qu  \
# 616          TA         TA      Plywood      Plywood    NaN           Gd
# 1327         TA         TA      MetalSd       CBlock  MnPrv          NaN
#
#       fireplaces foundation  full bath functional  garage area  garage cars  \
# 616            2       Slab          3        Typ    624.00000      2.00000
# 1327           0      PConc          1        Typ    280.00000      1.00000
#
#      garage cond garage finish garage qual garage type  garage yr blt  \
# 616           TA           Unf          TA      Attchd     1959.00000
# 1327          TA           Unf          TA      Detchd     1946.00000
#
#       gr liv area  half bath heating heating qc house style    id  \
# 616          3820          1    GasA         TA      1Story  1498
# 1327          896          0    GasA         TA      1Story  1342
#
#       kitchen abvgr kitchen qual land contour land slope  lot area lot config  \
# 616               1           Ex          Lvl        Gtl     47007     Inside
# 1327              1           TA          Lvl        Gtl      5940        FR3
#
#       lot frontage lot shape  low qual fin sf  ms subclass ms zoning  \
# 616      123.00000       IR1                0           20        RL
# 1327      99.00000       IR1                0           20        RM
#
#       mas vnr area mas vnr type misc feature  misc val  mo sold neighborhood  \
# 616        0.00000         None          NaN         0        7      Edwards
# 1327       0.00000         None          NaN         0        4      BrkSide
#
#       open porch sf  overall cond  overall qual        pid paved drive  \
# 616             372             7             5  908154080           Y
# 1327              0             7             4  903230120           Y
#
#       pool area pool qc roof matl roof style sale type  saleprice  \
# 616           0     NaN   CompShg      Gable       WD      284700
# 1327          0     NaN   CompShg      Gable     ConLD      79000
#
#       screen porch street  totrms abvgrd  total bsmt sf utilities  \
# 616              0   Pave             11        0.00000    AllPub
# 1327             0   Pave              4            NaN    AllPub
#
#       wood deck sf  year built  year remod/add  yr sold
# 616              0        1959            1996     2008
# 1327             0        1946            1950     2008

# %%
df[df['bsmt qual']=='NA'].head()
# Out:
#      1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 12         1288         728           0   NaN              4      1Fam
# 93         1535           0           0   NaN              4    Duplex
# 114         660           0           0   NaN              2      1Fam
# 146         495        1427           0   NaN              4      1Fam
# 183         733           0           0   NaN              2      1Fam
#
#     bsmt cond bsmt exposure  bsmt full bath  bsmt half bath bsmt qual  \
# 12         NA            NA         0.00000         0.00000        NA
# 93         NA            NA         0.00000         0.00000        NA
# 114        NA            NA         0.00000         0.00000        NA
# 146        NA            NA         0.00000         0.00000        NA
# 183        NA            NA         0.00000         0.00000        NA
#
#      bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 12       0.00000       0.00000       0.00000             NA             NA
# 93       0.00000       0.00000       0.00000             NA             NA
# 114      0.00000       0.00000       0.00000             NA             NA
# 146      0.00000       0.00000       0.00000             NA             NA
# 183      0.00000       0.00000       0.00000             NA             NA
#
#     central air condition 1 condition 2 electrical  enclosed porch exter cond  \
# 12            Y       Feedr        Norm      SBrkr               0         TA
# 93            Y        Norm        Norm      SBrkr               0         TA
# 114           N        Norm        Norm      SBrkr             100         TA
# 146           Y        Norm        Norm      SBrkr             177         TA
# 183           N        Norm        Norm      FuseA               0         Po
#
#     exter qual exterior 1st exterior 2nd  fence fireplace qu  fireplaces  \
# 12          Gd      HdBoard      HdBoard    NaN           TA           1
# 93          TA      HdBoard      HdBoard  GdPrv          NaN           0
# 114         TA      Wd Sdng      Wd Sdng    NaN          NaN           0
# 146         Gd      HdBoard      HdBoard    NaN           Ex           1
# 183         Fa      AsbShng      VinylSd    NaN          NaN           0
#
#     foundation  full bath functional  garage area  garage cars garage cond  \
# 12       PConc          1        Mod    576.00000      2.00000          TA
# 93        Slab          2        Typ    400.00000      2.00000          TA
# 114       Slab          1       Min2      0.00000      0.00000         NaN
# 146       Slab          3        Typ    672.00000      2.00000          TA
# 183       Slab          1        Sal    487.00000      2.00000          Po
#
#     garage finish garage qual garage type  garage yr blt  gr liv area  \
# 12            Unf          TA      Attchd     1900.00000         2016
# 93            Unf          TA      Attchd     1979.00000         1535
# 114           NaN         NaN         NaN            NaN          660
# 146           RFn          TA     BuiltIn     2003.00000         1922
# 183           Unf          Fa      Attchd     1952.00000          733
#
#      half bath heating heating qc house style    id  kitchen abvgr  \
# 12           0    GasA         Ex      2Story   807              1
# 93           0    GasA         TA      1Story   811              2
# 114          0    GasA         Fa      1Story   781              1
# 146          0    GasA         Ex      SFoyer   888              1
# 183          0    Wall         Po      1Story  1554              1
#
#     kitchen qual land contour land slope  lot area lot config  lot frontage  \
# 12            TA          Bnk        Gtl     26400        FR2     120.00000
# 93            TA          Bnk        Gtl      7018     Inside      64.00000
# 114           Fa          Lvl        Gtl      9000     Corner           NaN
# 146           Gd          Lvl        Gtl      7301     Corner      64.00000
# 183           Fa          Low        Mod     14584     Inside      80.00000
#
#     lot shape  low qual fin sf  ms subclass ms zoning  mas vnr area  \
# 12        Reg                0           70        RL       0.00000
# 93        Reg                0           90        RL       0.00000
# 114       Reg                0           20        RL       0.00000
# 146       Reg                0           85        RL     500.00000
# 183       Reg                0           20   A (agr)       0.00000
#
#     mas vnr type misc feature  misc val  mo sold neighborhood  open porch sf  \
# 12          None          NaN         0        6      SawyerW              0
# 93          None          NaN         0        6      SawyerW              0
# 114         None          NaN         0        6       Sawyer              0
# 146      BrkFace          NaN         0        7      Edwards              0
# 183         None          NaN         0        2       IDOTRR              0
#
#      overall cond  overall qual        pid paved drive  pool area pool qc  \
# 12              7             5  906226060           P          0     NaN
# 93              5             5  906226100           Y          0     NaN
# 114             2             2  905228050           N          0     NaN
# 146             5             7  908128060           Y          0     NaN
# 183             5             1  910251050           N          0     NaN
#
#     roof matl roof style sale type  saleprice  screen porch street  \
# 12    CompShg      Gable       WD      131000             0   Pave
# 93    CompShg      Gable       WD      118858             0   Pave
# 114   CompShg      Gable       WD       63900             0   Pave
# 146   CompShg      Gable     ConLD     198500             0   Pave
# 183   CompShg      Gable       WD       13100             0   Pave
#
#      totrms abvgrd  total bsmt sf utilities  wood deck sf  year built  \
# 12               7        0.00000    AllPub             0        1880
# 93               8        0.00000    AllPub             0        1979
# 114              5        0.00000    AllPub             0        1947
# 146              7        0.00000    AllPub             0        2003
# 183              4        0.00000    AllPub             0        1952
#
#      year remod/add  yr sold
# 12             2007     2009
# 93             1979     2009
# 114            1950     2009
# 146            2003     2009
# 183            1952     2008

# %%
basement_to_fix = ['bsmt full bath','bsmt half bath','bsmt unf sf','bsmtfin sf 1','bsmtfin sf 2']
for bsmt in basement_to_fix:
    df[bsmt] = df[bsmt].fillna(0)   # Replace NaN with 0 for all of the columns above
    
for bsmt in basement_to_fix:
    df_test[bsmt] = df_test[bsmt].fillna(0)

# %%
df[df['bsmt full bath'].isnull()].head()  # Verifying they have been fixed
# Out:
# Empty DataFrame
# Columns: [1st flr sf, 2nd flr sf, 3ssn porch, alley, bedroom abvgr, bldg type, bsmt cond, bsmt exposure, bsmt full bath, bsmt half bath, bsmt qual, bsmt unf sf, bsmtfin sf 1, bsmtfin sf 2, bsmtfin type 1, bsmtfin type 2, central air, condition 1, condition 2, electrical, enclosed porch, exter cond, exter qual, exterior 1st, exterior 2nd, fence, fireplace qu, fireplaces, foundation, full bath, functional, garage area, garage cars, garage cond, garage finish, garage qual, garage type, garage yr blt, gr liv area, half bath, heating, heating qc, house style, id, kitchen abvgr, kitchen qual, land contour, land slope, lot area, lot config, lot frontage, lot shape, low qual fin sf, ms subclass, ms zoning, mas vnr area, mas vnr type, misc feature, misc val, mo sold, neighborhood, open porch sf, overall cond, overall qual, pid, paved drive, pool area, pool qc, roof matl, roof style, sale type, saleprice, screen porch, street, totrms abvgrd, total bsmt sf, utilities, wood deck sf, year built, year remod/add, yr sold]
# Index: []

# %%
df.isnull().sum()     # basement features look good now, garage
# Out:
# 1st flr sf            0
# 2nd flr sf            0
# 3ssn porch            0
# alley              1911
# bedroom abvgr         0
# bldg type             0
# bsmt cond             0
# bsmt exposure         0
# bsmt full bath        0
# bsmt half bath        0
# bsmt qual             0
# bsmt unf sf           0
# bsmtfin sf 1          0
# bsmtfin sf 2          0
# bsmtfin type 1        0
# bsmtfin type 2        0
# central air           0
# condition 1           0
# condition 2           0
# electrical            0
# enclosed porch        0
# exter cond            0
# exter qual            0
# exterior 1st          0
# exterior 2nd          0
# fence              1651
# fireplace qu       1000
# fireplaces            0
# foundation            0
# full bath             0
# functional            0
# garage area           1
# garage cars           1
# garage cond         114
# garage finish       114
# garage qual         114
# garage type         113
# garage yr blt       114
# gr liv area           0
# half bath             0
# heating               0
# heating qc            0
# house style           0
# id                    0
# kitchen abvgr         0
# kitchen qual          0
# land contour          0
# land slope            0
# lot area              0
# lot config            0
# lot frontage        330
# lot shape             0
# low qual fin sf       0
# ms subclass           0
# ms zoning             0
# mas vnr area         22
# mas vnr type         22
# misc feature       1986
# misc val              0
# mo sold               0
# neighborhood          0
# open porch sf         0
# overall cond          0
# overall qual          0
# pid                   0
# paved drive           0
# pool area             0
# pool qc            2042
# roof matl             0
# roof style            0
# sale type             0
# saleprice             0
# screen porch          0
# street                0
# totrms abvgrd         0
# total bsmt sf         1
# utilities             0
# wood deck sf          0
# year built            0
# year remod/add        0
# yr sold               0
# dtype: int64

# %%
df['garage type'].value_counts()  

# Documentation says that garag qual should be NA if there is no basement, NA is missing
# same for Garage Finish, Garage Qual, Garage Cond
# Out:
# Attchd     1213
# Detchd      536
# BuiltIn     132
# Basment      27
# 2Types       19
# CarPort      11
# Name: garage type, dtype: int64

# %%
garage_to_fix = ['garage type','garage finish', 'garage qual', 'garage cond']
for grg in garage_to_fix:
    df[grg] = df[grg].fillna('NA')    # Replace NaN with NA for all of the columns above
    
for grg in garage_to_fix:
    df_test[grg] = df_test[grg].fillna('NA')    # Replace NaN with NA for all of the columns above

# %%
df.isnull().sum()     # Garage values look better, except for garage area(1), garage cars(1), and garage yr blt(114) ?
# Out:
# 1st flr sf            0
# 2nd flr sf            0
# 3ssn porch            0
# alley              1911
# bedroom abvgr         0
# bldg type             0
# bsmt cond             0
# bsmt exposure         0
# bsmt full bath        0
# bsmt half bath        0
# bsmt qual             0
# bsmt unf sf           0
# bsmtfin sf 1          0
# bsmtfin sf 2          0
# bsmtfin type 1        0
# bsmtfin type 2        0
# central air           0
# condition 1           0
# condition 2           0
# electrical            0
# enclosed porch        0
# exter cond            0
# exter qual            0
# exterior 1st          0
# exterior 2nd          0
# fence              1651
# fireplace qu       1000
# fireplaces            0
# foundation            0
# full bath             0
# functional            0
# garage area           1
# garage cars           1
# garage cond           0
# garage finish         0
# garage qual           0
# garage type           0
# garage yr blt       114
# gr liv area           0
# half bath             0
# heating               0
# heating qc            0
# house style           0
# id                    0
# kitchen abvgr         0
# kitchen qual          0
# land contour          0
# land slope            0
# lot area              0
# lot config            0
# lot frontage        330
# lot shape             0
# low qual fin sf       0
# ms subclass           0
# ms zoning             0
# mas vnr area         22
# mas vnr type         22
# misc feature       1986
# misc val              0
# mo sold               0
# neighborhood          0
# open porch sf         0
# overall cond          0
# overall qual          0
# pid                   0
# paved drive           0
# pool area             0
# pool qc            2042
# roof matl             0
# roof style            0
# sale type             0
# saleprice             0
# screen porch          0
# street                0
# totrms abvgrd         0
# total bsmt sf         1
# utilities             0
# wood deck sf          0
# year built            0
# year remod/add        0
# yr sold               0
# dtype: int64

# %%
df[df['garage area'].isnull()].head()    # looks like there is no garage here, so garage area and garage cars should both be 0
# Out:
#       1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 1712         942         886           0   NaN              3      1Fam
#
#      bsmt cond bsmt exposure  bsmt full bath  bsmt half bath bsmt qual  \
# 1712        TA            No         0.00000         0.00000        Gd
#
#       bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 1712    311.00000     548.00000       0.00000            ALQ            Unf
#
#      central air condition 1 condition 2 electrical  enclosed porch  \
# 1712           Y        Norm        Norm      SBrkr             212
#
#      exter cond exter qual exterior 1st exterior 2nd  fence fireplace qu  \
# 1712         TA         TA      Wd Sdng      Plywood  MnPrv          NaN
#
#       fireplaces foundation  full bath functional  garage area  garage cars  \
# 1712           0     BrkTil          2        Typ          NaN          NaN
#
#      garage cond garage finish garage qual garage type  garage yr blt  \
# 1712          NA            NA          NA      Detchd            NaN
#
#       gr liv area  half bath heating heating qc house style    id  \
# 1712         1828          0    GasA         Ex      2Story  2237
#
#       kitchen abvgr kitchen qual land contour land slope  lot area lot config  \
# 1712              1           Gd          Lvl        Gtl      9060     Inside
#
#       lot frontage lot shape  low qual fin sf  ms subclass ms zoning  \
# 1712      50.00000       Reg                0           70        RM
#
#       mas vnr area mas vnr type misc feature  misc val  mo sold neighborhood  \
# 1712       0.00000         None          NaN         0        3       IDOTRR
#
#       open porch sf  overall cond  overall qual        pid paved drive  \
# 1712              0             6             5  910201180           Y
#
#       pool area pool qc roof matl roof style sale type  saleprice  \
# 1712          0     NaN   CompShg      Gable       WD      150909
#
#       screen porch street  totrms abvgrd  total bsmt sf utilities  \
# 1712             0   Pave              6      859.00000    AllPub
#
#       wood deck sf  year built  year remod/add  yr sold
# 1712           174        1923            1999     2007

# %%
df['garage area'] = df['garage area'].fillna(0)
df['garage cars'] = df['garage cars'].fillna(0)

df_test['garage area'] = df_test['garage area'].fillna(0)
df_test['garage cars'] = df_test['garage cars'].fillna(0)

# %%
df.isnull().sum() # Verifying that garage looks good except for garage yr blt, probably should be 0 or na? if there is no garage
# Out:
# 1st flr sf            0
# 2nd flr sf            0
# 3ssn porch            0
# alley              1911
# bedroom abvgr         0
# bldg type             0
# bsmt cond             0
# bsmt exposure         0
# bsmt full bath        0
# bsmt half bath        0
# bsmt qual             0
# bsmt unf sf           0
# bsmtfin sf 1          0
# bsmtfin sf 2          0
# bsmtfin type 1        0
# bsmtfin type 2        0
# central air           0
# condition 1           0
# condition 2           0
# electrical            0
# enclosed porch        0
# exter cond            0
# exter qual            0
# exterior 1st          0
# exterior 2nd          0
# fence              1651
# fireplace qu       1000
# fireplaces            0
# foundation            0
# full bath             0
# functional            0
# garage area           0
# garage cars           0
# garage cond           0
# garage finish         0
# garage qual           0
# garage type           0
# garage yr blt       114
# gr liv area           0
# half bath             0
# heating               0
# heating qc            0
# house style           0
# id                    0
# kitchen abvgr         0
# kitchen qual          0
# land contour          0
# land slope            0
# lot area              0
# lot config            0
# lot frontage        330
# lot shape             0
# low qual fin sf       0
# ms subclass           0
# ms zoning             0
# mas vnr area         22
# mas vnr type         22
# misc feature       1986
# misc val              0
# mo sold               0
# neighborhood          0
# open porch sf         0
# overall cond          0
# overall qual          0
# pid                   0
# paved drive           0
# pool area             0
# pool qc            2042
# roof matl             0
# roof style            0
# sale type             0
# saleprice             0
# screen porch          0
# street                0
# totrms abvgrd         0
# total bsmt sf         1
# utilities             0
# wood deck sf          0
# year built            0
# year remod/add        0
# yr sold               0
# dtype: int64

# %%
garage_check = df[df['garage type']=='NA'] 
garage_check['garage yr blt'].value_counts()   # For all of the garage type NA, there isn't a single value for garage yr blt.  Those should be NA
# Out:
# Series([], Name: garage yr blt, dtype: int64)

# %%
df[df['garage yr blt']=='NA'] # There are no other NA's, and the documentation isn't clear.  We will be putting in NA's to get rid of the nulls
# Out:
# Empty DataFrame
# Columns: [1st flr sf, 2nd flr sf, 3ssn porch, alley, bedroom abvgr, bldg type, bsmt cond, bsmt exposure, bsmt full bath, bsmt half bath, bsmt qual, bsmt unf sf, bsmtfin sf 1, bsmtfin sf 2, bsmtfin type 1, bsmtfin type 2, central air, condition 1, condition 2, electrical, enclosed porch, exter cond, exter qual, exterior 1st, exterior 2nd, fence, fireplace qu, fireplaces, foundation, full bath, functional, garage area, garage cars, garage cond, garage finish, garage qual, garage type, garage yr blt, gr liv area, half bath, heating, heating qc, house style, id, kitchen abvgr, kitchen qual, land contour, land slope, lot area, lot config, lot frontage, lot shape, low qual fin sf, ms subclass, ms zoning, mas vnr area, mas vnr type, misc feature, misc val, mo sold, neighborhood, open porch sf, overall cond, overall qual, pid, paved drive, pool area, pool qc, roof matl, roof style, sale type, saleprice, screen porch, street, totrms abvgrd, total bsmt sf, utilities, wood deck sf, year built, year remod/add, yr sold]
# Index: []

# %%
df['garage yr blt'] = df['garage yr blt'].fillna('NA')
df_test['garage yr blt'] = df_test['garage yr blt'].fillna('NA')

df['garage yr blt'].isnull().sum() # No more null values
# Out:
# 0

# %%
df.isnull().sum() # Looking for other small hits
# total bsmt sf probably should have been fixed with the other basement stuff
# Out:
# 1st flr sf            0
# 2nd flr sf            0
# 3ssn porch            0
# alley              1911
# bedroom abvgr         0
# bldg type             0
# bsmt cond             0
# bsmt exposure         0
# bsmt full bath        0
# bsmt half bath        0
# bsmt qual             0
# bsmt unf sf           0
# bsmtfin sf 1          0
# bsmtfin sf 2          0
# bsmtfin type 1        0
# bsmtfin type 2        0
# central air           0
# condition 1           0
# condition 2           0
# electrical            0
# enclosed porch        0
# exter cond            0
# exter qual            0
# exterior 1st          0
# exterior 2nd          0
# fence              1651
# fireplace qu       1000
# fireplaces            0
# foundation            0
# full bath             0
# functional            0
# garage area           0
# garage cars           0
# garage cond           0
# garage finish         0
# garage qual           0
# garage type           0
# garage yr blt         0
# gr liv area           0
# half bath             0
# heating               0
# heating qc            0
# house style           0
# id                    0
# kitchen abvgr         0
# kitchen qual          0
# land contour          0
# land slope            0
# lot area              0
# lot config            0
# lot frontage        330
# lot shape             0
# low qual fin sf       0
# ms subclass           0
# ms zoning             0
# mas vnr area         22
# mas vnr type         22
# misc feature       1986
# misc val              0
# mo sold               0
# neighborhood          0
# open porch sf         0
# overall cond          0
# overall qual          0
# pid                   0
# paved drive           0
# pool area             0
# pool qc            2042
# roof matl             0
# roof style            0
# sale type             0
# saleprice             0
# screen porch          0
# street                0
# totrms abvgrd         0
# total bsmt sf         1
# utilities             0
# wood deck sf          0
# year built            0
# year remod/add        0
# yr sold               0
# dtype: int64

# %%
df[df['total bsmt sf'].isnull()].head()  # looks like there is not basement anyway
# Out:
#       1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 1327         896           0           0   NaN              2      1Fam
#
#      bsmt cond bsmt exposure  bsmt full bath  bsmt half bath bsmt qual  \
# 1327        NA            NA         0.00000         0.00000        NA
#
#       bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 1327      0.00000       0.00000       0.00000             NA             NA
#
#      central air condition 1 condition 2 electrical  enclosed porch  \
# 1327           Y       Feedr        Norm      FuseA               0
#
#      exter cond exter qual exterior 1st exterior 2nd  fence fireplace qu  \
# 1327         TA         TA      MetalSd       CBlock  MnPrv          NaN
#
#       fireplaces foundation  full bath functional  garage area  garage cars  \
# 1327           0      PConc          1        Typ    280.00000      1.00000
#
#      garage cond garage finish garage qual garage type garage yr blt  \
# 1327          TA           Unf          TA      Detchd    1946.00000
#
#       gr liv area  half bath heating heating qc house style    id  \
# 1327          896          0    GasA         TA      1Story  1342
#
#       kitchen abvgr kitchen qual land contour land slope  lot area lot config  \
# 1327              1           TA          Lvl        Gtl      5940        FR3
#
#       lot frontage lot shape  low qual fin sf  ms subclass ms zoning  \
# 1327      99.00000       IR1                0           20        RM
#
#       mas vnr area mas vnr type misc feature  misc val  mo sold neighborhood  \
# 1327       0.00000         None          NaN         0        4      BrkSide
#
#       open porch sf  overall cond  overall qual        pid paved drive  \
# 1327              0             7             4  903230120           Y
#
#       pool area pool qc roof matl roof style sale type  saleprice  \
# 1327          0     NaN   CompShg      Gable     ConLD      79000
#
#       screen porch street  totrms abvgrd  total bsmt sf utilities  \
# 1327             0   Pave              4            NaN    AllPub
#
#       wood deck sf  year built  year remod/add  yr sold
# 1327             0        1946            1950     2008

# %%
df['total bsmt sf'] = df['total bsmt sf'].fillna(0) 
df_test['total bsmt sf'] = df_test['total bsmt sf'].fillna(0)

# %%
df.isnull().sum() # generally looking good
# little stuff to fix includes 'mas vnr area' and ' mas vnr type '
# big hits include 'alley', 'fence', 'fireplace qu','lot frontage','misc feature','pool qc '

# 'mas vnr type' should include a None value, so 'mas vnr area' should probablly include 0's
# Out:
# 1st flr sf            0
# 2nd flr sf            0
# 3ssn porch            0
# alley              1911
# bedroom abvgr         0
# bldg type             0
# bsmt cond             0
# bsmt exposure         0
# bsmt full bath        0
# bsmt half bath        0
# bsmt qual             0
# bsmt unf sf           0
# bsmtfin sf 1          0
# bsmtfin sf 2          0
# bsmtfin type 1        0
# bsmtfin type 2        0
# central air           0
# condition 1           0
# condition 2           0
# electrical            0
# enclosed porch        0
# exter cond            0
# exter qual            0
# exterior 1st          0
# exterior 2nd          0
# fence              1651
# fireplace qu       1000
# fireplaces            0
# foundation            0
# full bath             0
# functional            0
# garage area           0
# garage cars           0
# garage cond           0
# garage finish         0
# garage qual           0
# garage type           0
# garage yr blt         0
# gr liv area           0
# half bath             0
# heating               0
# heating qc            0
# house style           0
# id                    0
# kitchen abvgr         0
# kitchen qual          0
# land contour          0
# land slope            0
# lot area              0
# lot config            0
# lot frontage        330
# lot shape             0
# low qual fin sf       0
# ms subclass           0
# ms zoning             0
# mas vnr area         22
# mas vnr type         22
# misc feature       1986
# misc val              0
# mo sold               0
# neighborhood          0
# open porch sf         0
# overall cond          0
# overall qual          0
# pid                   0
# paved drive           0
# pool area             0
# pool qc            2042
# roof matl             0
# roof style            0
# sale type             0
# saleprice             0
# screen porch          0
# street                0
# totrms abvgrd         0
# total bsmt sf         0
# utilities             0
# wood deck sf          0
# year built            0
# year remod/add        0
# yr sold               0
# dtype: int64

# %%
df[df['mas vnr area'].isnull()]
# looks like all the 'mas vnr area' NaN's are also 'mas vnr type' NaN's.   Setting type to None, and area to 0.
# Out:
#       1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 22          1209        1044           0   NaN              3      1Fam
# 41          2076           0           0   NaN              2      1Fam
# 86          1200           0           0   NaN              2      1Fam
# 212         1436           0           0   NaN              3      1Fam
# 276          914           0           0   NaN              2      1Fam
# 338          955         925           0   NaN              3      1Fam
# 431         1128         903           0   NaN              3      1Fam
# 451         1460           0           0   NaN              3      1Fam
# 591         1241           0           0  Pave              1    TwnhsE
# 844         1550           0           0  Pave              2    TwnhsE
# 913         2515           0           0   NaN              4      1Fam
# 939         1428           0           0   NaN              3      1Fam
# 1025        1528           0           0   NaN              3      1Fam
# 1244         878        1126           0   NaN              4      1Fam
# 1306         754         640           0   NaN              3      1Fam
# 1430         952         860           0   NaN              3      1Fam
# 1434         822         843           0   NaN              3      1Fam
# 1606         707         707           0   NaN              3      1Fam
# 1699        1564           0           0   NaN              2      1Fam
# 1815        1670           0           0   NaN              2      1Fam
# 1820         768         728           0   NaN              3      1Fam
# 1941         860        1100           0   NaN              4      1Fam
#
#      bsmt cond bsmt exposure  bsmt full bath  bsmt half bath bsmt qual  \
# 22          TA            Av         0.00000         0.00000        Ex
# 41          Gd            Gd         1.00000         0.00000        Ex
# 86          TA            No         1.00000         0.00000        Gd
# 212         TA            No         0.00000         0.00000        Ex
# 276         TA            Av         1.00000         0.00000        Gd
# 338         TA            Av         1.00000         0.00000        Ex
# 431         TA            No         1.00000         0.00000        Gd
# 451         TA            No         0.00000         0.00000        Ex
# 591         TA            No         1.00000         0.00000        Gd
# 844         TA            No         0.00000         0.00000        Gd
# 913         TA            No         1.00000         0.00000        TA
# 939         TA            No         0.00000         0.00000        Gd
# 1025        TA            No         0.00000         0.00000        Gd
# 1244        TA            No         1.00000         0.00000        Ex
# 1306        TA            No         0.00000         0.00000        Gd
# 1430        TA            No         0.00000         0.00000        Gd
# 1434        TA            No         0.00000         0.00000        Gd
# 1606        TA            No         0.00000         0.00000        Gd
# 1699        TA            Av         0.00000         0.00000        Gd
# 1815        Gd            No         1.00000         0.00000        Ex
# 1820        TA            No         0.00000         0.00000        Gd
# 1941        TA            No         1.00000         0.00000        Gd
#
#       bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 22     1209.00000       0.00000       0.00000            Unf            Unf
# 41      690.00000    1386.00000       0.00000            GLQ            Unf
# 86      343.00000     833.00000       0.00000            GLQ            Unf
# 212    1436.00000       0.00000       0.00000            Unf            Unf
# 276     142.00000     475.00000     297.00000            GLQ            ALQ
# 338     210.00000     745.00000       0.00000            GLQ            Unf
# 431     324.00000     804.00000       0.00000            GLQ            Unf
# 451     794.00000     666.00000       0.00000            GLQ            Unf
# 591     135.00000    1106.00000       0.00000            GLQ            Unf
# 844    1550.00000       0.00000       0.00000            Unf            Unf
# 913     816.00000    1219.00000       0.00000            Rec            Unf
# 939    1428.00000       0.00000       0.00000            Unf            Unf
# 1025   1528.00000       0.00000       0.00000            Unf            Unf
# 1244    219.00000     651.00000       0.00000            GLQ            Unf
# 1306    384.00000       0.00000       0.00000            Unf            Unf
# 1430    952.00000       0.00000       0.00000            Unf            Unf
# 1434    813.00000       0.00000       0.00000            Unf            Unf
# 1606    707.00000       0.00000       0.00000            Unf            Unf
# 1699    963.00000     583.00000       0.00000            GLQ            Unf
# 1815    108.00000    1562.00000       0.00000            GLQ            Unf
# 1820    768.00000       0.00000       0.00000            Unf            Unf
# 1941    235.00000     625.00000       0.00000            GLQ            Unf
#
#      central air condition 1 condition 2 electrical  enclosed porch  \
# 22             Y        Norm        Norm      SBrkr               0
# 41             Y        Norm        Norm      SBrkr               0
# 86             Y        Norm        Norm      SBrkr               0
# 212            Y        Norm        Norm      SBrkr               0
# 276            Y        Norm        Norm      SBrkr               0
# 338            Y        Norm        Norm      SBrkr               0
# 431            Y        Norm        Norm      SBrkr               0
# 451            Y       Feedr        Norm      SBrkr               0
# 591            Y        Norm        Norm      SBrkr               0
# 844            Y        Norm        Norm      SBrkr               0
# 913            Y        Norm        Norm      SBrkr             200
# 939            Y        Norm        Norm      SBrkr               0
# 1025           Y       Feedr        Norm      SBrkr               0
# 1244           Y        Norm        Norm      SBrkr               0
# 1306           Y        Norm        Norm      SBrkr               0
# 1430           Y        Norm        Norm      SBrkr               0
# 1434           Y        Norm        Norm      SBrkr               0
# 1606           Y        RRAn        Norm      SBrkr               0
# 1699           Y        Norm        Norm      SBrkr               0
# 1815           Y        RRAn        Norm      SBrkr             200
# 1820           Y        RRAn        Norm      SBrkr               0
# 1941           Y        Norm        Norm      SBrkr               0
#
#      exter cond exter qual exterior 1st exterior 2nd fence fireplace qu  \
# 22           TA         Gd      CemntBd      CmentBd   NaN           Gd
# 41           TA         Ex      VinylSd      VinylSd   NaN           Gd
# 86           TA         Gd      VinylSd      VinylSd   NaN          NaN
# 212          TA         Gd      VinylSd      VinylSd   NaN          NaN
# 276          TA         TA      VinylSd      VinylSd   NaN          NaN
# 338          TA         Gd      WdShing      Wd Shng   NaN           Gd
# 431          TA         Gd      VinylSd      VinylSd   NaN           Gd
# 451          TA         Gd      VinylSd      VinylSd   NaN           Gd
# 591          TA         Gd      VinylSd      VinylSd   NaN          NaN
# 844          TA         Gd      VinylSd      VinylSd   NaN          NaN
# 913          TA         Gd      Wd Sdng        Stone   NaN           TA
# 939          TA         Gd      CemntBd      CmentBd   NaN          NaN
# 1025         TA         Gd      VinylSd      VinylSd   NaN           TA
# 1244         TA         Gd      VinylSd      VinylSd   NaN           Gd
# 1306         TA         Gd      VinylSd      VinylSd   NaN           TA
# 1430         TA         Gd      VinylSd      VinylSd   NaN           TA
# 1434         TA         Gd      CemntBd      CmentBd   NaN          NaN
# 1606         TA         Gd      VinylSd      VinylSd   NaN           Gd
# 1699         TA         Gd      VinylSd      VinylSd   NaN           Gd
# 1815         TA         Gd      VinylSd      VinylSd   NaN           Gd
# 1820         TA         Gd      VinylSd      VinylSd   NaN          NaN
# 1941         TA         Gd      VinylSd      VinylSd   NaN           TA
#
#       fireplaces foundation  full bath functional  garage area  garage cars  \
# 22             1      PConc          2        Typ    575.00000      2.00000
# 41             1      PConc          2        Typ    850.00000      3.00000
# 86             0      PConc          2        Typ    555.00000      2.00000
# 212            0      PConc          2        Typ    529.00000      2.00000
# 276            0      PConc          1        Typ      0.00000      0.00000
# 338            1      PConc          2        Typ    880.00000      3.00000
# 431            1      PConc          2        Typ    577.00000      2.00000
# 451            1      PConc          2        Typ    480.00000      2.00000
# 591            0      PConc          1        Typ    569.00000      2.00000
# 844            0      PConc          2        Typ    528.00000      2.00000
# 913            2      PConc          3       Maj1    484.00000      2.00000
# 939            0      PConc          2        Typ    480.00000      2.00000
# 1025           1      PConc          3        Typ    480.00000      2.00000
# 1244           1      PConc          2        Typ    644.00000      3.00000
# 1306           1      PConc          2        Typ    400.00000      2.00000
# 1430           1      PConc          2        Typ    469.00000      2.00000
# 1434           0      PConc          2        Typ    562.00000      2.00000
# 1606           1      PConc          2        Typ    403.00000      2.00000
# 1699           1      PConc          2        Typ    502.00000      2.00000
# 1815           1      PConc          2        Typ    928.00000      3.00000
# 1820           0     CBlock          3        Typ    572.00000      2.00000
# 1941           2      PConc          2        Typ    440.00000      2.00000
#
#      garage cond garage finish garage qual garage type garage yr blt  \
# 22            TA           Fin          TA      Attchd    2005.00000
# 41            TA           Fin          TA      Attchd    2006.00000
# 86            TA           RFn          TA      Attchd    2003.00000
# 212           TA           Fin          TA      Attchd    2008.00000
# 276           NA            NA          NA          NA            NA
# 338           TA           Fin          TA      Attchd    2007.00000
# 431           TA           RFn          TA      Attchd    2002.00000
# 451           TA           Fin          TA      Attchd    2006.00000
# 591           TA           Fin          TA      Attchd    2007.00000
# 844           TA           Fin          TA      Attchd    2007.00000
# 913           TA           RFn          TA      Attchd    1975.00000
# 939           TA           Fin          TA      Attchd    2007.00000
# 1025          TA           Unf          TA      Attchd    2007.00000
# 1244          TA           Fin          TA     BuiltIn    2002.00000
# 1306          TA           Fin          TA     BuiltIn    2003.00000
# 1430          TA           RFn          TA      Attchd    2002.00000
# 1434          TA           RFn          TA      Attchd    2007.00000
# 1606          TA           Fin          TA      Attchd    2002.00000
# 1699          TA           RFn          TA      Attchd    2207.00000
# 1815          TA           RFn          TA      Attchd    2006.00000
# 1820          TA           Unf          TA      Attchd    2007.00000
# 1941          TA           Fin          TA     BuiltIn    2002.00000
#
#       gr liv area  half bath heating heating qc house style    id  \
# 22           2253          1    GasA         Ex      2Story  2393
# 41           2076          1    GasA         Ex      1Story  2383
# 86           1200          0    GasA         Ex      1Story   539
# 212          1436          0    GasA         Ex      1Story   518
# 276           914          0    GasA         Ex      1Story  2824
# 338          1880          1    GasA         Ex      2Story  1800
# 431          2031          1    GasA         Ex      2Story  1455
# 451          1460          0    GasA         Ex      1Story  1120
# 591          1241          1    GasA         Ex      1Story  1841
# 844          1550          1    GasA         Ex      1Story  1840
# 913          2515          0    GasA         TA      1Story  2230
# 939          1428          0    GasA         Ex      1Story  1123
# 1025         1528          2    GasA         Ex      1Story  1784
# 1244         2004          1    GasA         Ex      2Story   485
# 1306         1394          1    GasA         Ex        SLvl  1752
# 1430         1812          1    GasA         Ex      2Story  1185
# 1434         1665          1    GasA         Ex      2Story  1128
# 1606         1414          1    GasA         Ex      2Story  1096
# 1699         1564          0    GasA         Ex      1Story  2261
# 1815         1670          1    GasA         Ex      1Story  2456
# 1820         1496          0    GasA         Ex      2Story  1728
# 1941         1960          1    GasA         Ex      2Story    56
#
#       kitchen abvgr kitchen qual land contour land slope  lot area lot config  \
# 22                1           Ex          Lvl        Gtl     12867     Corner
# 41                1           Ex          Lvl        Gtl     13891     Inside
# 86                1           Gd          Lvl        Gtl     10083     Inside
# 212               1           Gd          Lvl        Gtl      7993     Inside
# 276               1           Gd          Lvl        Gtl      8050     Inside
# 338               1           Ex          Lvl        Gtl     12217     Inside
# 431               1           Gd          Lvl        Gtl      9473     Inside
# 451               1           Gd          Lvl        Gtl     10037     Corner
# 591               1           Gd          Lvl        Gtl      4274     Inside
# 844               1           Gd          Lvl        Gtl      5330     Inside
# 913               2           TA          Lvl        Gtl     32668    CulDSac
# 939               1           Gd          Lvl        Gtl     11639     Corner
# 1025              1           Gd          Lvl        Gtl      9965        FR2
# 1244              1           Gd          Lvl        Gtl     12891     Corner
# 1306              1           Gd          Lvl        Gtl     11950     Corner
# 1430              1           TA          Lvl        Gtl      7500     Inside
# 1434              1           Gd          Lvl        Gtl      8125     Inside
# 1606              1           Gd          Lvl        Gtl      7750     Inside
# 1699              1           Ex          HLS        Gtl      8298     Inside
# 1815              1           Gd          Lvl        Gtl     15218    CulDSac
# 1820              1           Gd          Lvl        Gtl     15810     Inside
# 1941              1           Gd          Lvl        Gtl      7851     Inside
#
#       lot frontage lot shape  low qual fin sf  ms subclass ms zoning  \
# 22       103.00000       IR1                0           60        RL
# 41       107.00000       Reg                0           20        RL
# 86        67.00000       Reg                0           20        RL
# 212       90.00000       IR1                0           20        FV
# 276       75.00000       Reg                0           20        RL
# 338      112.00000       IR1                0           60        FV
# 431       75.00000       Reg                0           60        RL
# 451       87.00000       Reg                0           20        RL
# 591       35.00000       IR1                0          120        FV
# 844       30.00000       IR2                0          120        FV
# 913            NaN       IR1                0           20        RL
# 939       95.00000       Reg                0           20        FV
# 1025      85.00000       Reg                0           20        RL
# 1244           NaN       IR1                0           60        RL
# 1306           NaN       IR1                0           80        RL
# 1430           NaN       Reg                0           60        FV
# 1434      65.00000       Reg                0           60        FV
# 1606           NaN       Reg                0           60        RL
# 1699      68.00000       IR1                0           20        RL
# 1815      49.00000       IR1                0           20        RL
# 1820      59.00000       IR1                0           60        RL
# 1941           NaN       Reg                0           60        RL
#
#       mas vnr area mas vnr type misc feature  misc val  mo sold neighborhood  \
# 22             NaN          NaN          NaN         0        7      NridgHt
# 41             NaN          NaN          NaN         0        9      NridgHt
# 86             NaN          NaN          NaN         0        8      SawyerW
# 212            NaN          NaN          NaN         0       10      Somerst
# 276            NaN          NaN          NaN         0        4      Edwards
# 338            NaN          NaN          NaN         0       12      Somerst
# 431            NaN          NaN          NaN         0        3      CollgCr
# 451            NaN          NaN          NaN         0        8      Somerst
# 591            NaN          NaN          NaN         0       11      Somerst
# 844            NaN          NaN          NaN         0        7      Somerst
# 913            NaN          NaN          NaN         0        3      Crawfor
# 939            NaN          NaN          NaN         0       12      Somerst
# 1025           NaN          NaN          NaN         0        9      Somerst
# 1244           NaN          NaN          NaN         0        7      Gilbert
# 1306           NaN          NaN          NaN         0       10      Gilbert
# 1430           NaN          NaN          NaN         0        4      Somerst
# 1434           NaN          NaN          NaN         0        5      Somerst
# 1606           NaN          NaN          NaN         0        4      Gilbert
# 1699           NaN          NaN          NaN         0        9       Timber
# 1815           NaN          NaN          NaN         0        9      Somerst
# 1820           NaN          NaN          NaN         0        5      Gilbert
# 1941           NaN          NaN          NaN         0        5      Gilbert
#
#       open porch sf  overall cond  overall qual        pid paved drive  \
# 22              142             5             8  528142010           Y
# 41              229             5            10  528110050           Y
# 86               41             5             7  531371050           Y
# 212             121             5             7  528458020           Y
# 276               0             5             6  908130020           N
# 338             127             5             8  528458150           Y
# 431             211             5             8  907251090           Y
# 451              20             5             8  528439010           Y
# 591             116             5             7  533208040           Y
# 844             102             5             8  533208030           Y
# 913               0             3             6  909475070           Y
# 939             120             5             7  528462040           Y
# 1025            228             5             7  528435010           Y
# 1244             48             5             8  528275160           Y
# 1306              0             5             7  528250010           Y
# 1430            112             5             7  534104100           Y
# 1434              0             6             7  528480160           Y
# 1606             35             5             7  528290090           Y
# 1699              0             5             8  916384070           Y
# 1815            240             5             8  528429100           Y
# 1820              0             5             6  528218010           Y
# 1941             48             5             6  528240070           Y
#
#       pool area pool qc roof matl roof style sale type  saleprice  \
# 22            0     NaN   CompShg      Gable       New     344133
# 41            0     NaN   CompShg      Gable       New     465000
# 86            0     NaN   CompShg      Gable       WD      184900
# 212           0     NaN   CompShg      Gable       New     225000
# 276           0     NaN   CompShg      Gable       WD      117250
# 338           0     NaN   CompShg        Hip       New     310013
# 431           0     NaN   CompShg      Gable       WD      237000
# 451           0     NaN   CompShg        Hip       WD      247000
# 591           0     NaN   CompShg      Gable       New     199900
# 844           0     NaN   CompShg      Gable       New     207500
# 913           0     NaN   CompShg        Hip       WD      200624
# 939           0     NaN   CompShg      Gable       New     182000
# 1025          0     NaN   CompShg      Gable       New     235876
# 1244          0     NaN   CompShg      Gable       WD      257500
# 1306          0     NaN   CompShg      Gable       WD      165500
# 1430          0     NaN   CompShg      Gable       WD      205000
# 1434          0     NaN   CompShg      Gable       WD      205950
# 1606          0     NaN   CompShg      Gable       WD      176000
# 1699          0     NaN   CompShg        Hip       New     267300
# 1815          0     NaN   CompShg      Gable       New     336820
# 1820          0     NaN   CompShg      Gable       New     181755
# 1941          0     NaN   CompShg      Gable       WD      216500
#
#       screen porch street  totrms abvgrd  total bsmt sf utilities  \
# 22               0   Pave              8     1209.00000    AllPub
# 41               0   Pave              7     2076.00000    AllPub
# 86               0   Pave              5     1176.00000    AllPub
# 212              0   Pave              6     1436.00000    AllPub
# 276              0   Pave              4      914.00000    AllPub
# 338              0   Pave              8      955.00000    AllPub
# 431              0   Pave              7     1128.00000    AllPub
# 451              0   Pave              6     1460.00000    AllPub
# 591              0   Pave              4     1241.00000    AllPub
# 844              0   Pave              5     1550.00000    AllPub
# 913              0   Pave              9     2035.00000    AllPub
# 939              0   Pave              6     1428.00000    AllPub
# 1025             0   Pave              6     1528.00000    AllPub
# 1244             0   Pave              8      870.00000    AllPub
# 1306             0   Pave              7      384.00000    AllPub
# 1430             0   Pave              7      952.00000    AllPub
# 1434             0   Pave              7      813.00000    AllPub
# 1606             0   Pave              6      707.00000    AllPub
# 1699             0   Pave              6     1546.00000    AllPub
# 1815             0   Pave              6     1670.00000    AllPub
# 1820             0   Pave              7      768.00000    AllPub
# 1941             0   Pave              8      860.00000    AllPub
#
#       wood deck sf  year built  year remod/add  yr sold
# 22             243        2005            2006     2006
# 41             216        2006            2006     2006
# 86               0        2003            2003     2009
# 212              0        2008            2009     2009
# 276             32        2002            2002     2006
# 338            168        2007            2007     2007
# 431              0        2002            2002     2008
# 451              0        2006            2007     2008
# 591              0        2006            2007     2007
# 844              0        2006            2007     2007
# 913              0        1957            1975     2007
# 939              0        2007            2008     2008
# 1025             0        2007            2007     2007
# 1244             0        2002            2002     2009
# 1306           100        2003            2003     2007
# 1430           144        2002            2002     2008
# 1434             0        2007            2007     2008
# 1606           100        2002            2002     2008
# 1699           132        2006            2007     2007
# 1815             0        2006            2006     2006
# 1820           100        2007            2007     2007
# 1941           288        2002            2002     2010

# %%
df['mas vnr area'] = df['mas vnr area'].fillna(0) 
df['mas vnr type'] = df['mas vnr type'].fillna('None') 

df_test['mas vnr area'] = df_test['mas vnr area'].fillna(0) 
df_test['mas vnr type'] = df_test['mas vnr type'].fillna('None')

# %%
df['mas vnr type'].value_counts()
# Out:
# None       1240
# BrkFace     630
# Stone       168
# BrkCmn       13
# Name: mas vnr type, dtype: int64

# %%
df.isnull().sum()
# big hits left 'alley', 'fence', 'fireplace qu','lot frontage','misc feature','pool qc '
# alley should have an NA = No Alley Access
# fence should habe an NA = No Fence
# fireplace qu sould have an NA = No Fireplace
# lot fontage might be relating to lot config, lot shape, or lot area, defined as Linear feet of street connected to property, would expect every lot to have something
# pool QC sould have an NA = No Pool
# Out:
# 1st flr sf            0
# 2nd flr sf            0
# 3ssn porch            0
# alley              1911
# bedroom abvgr         0
# bldg type             0
# bsmt cond             0
# bsmt exposure         0
# bsmt full bath        0
# bsmt half bath        0
# bsmt qual             0
# bsmt unf sf           0
# bsmtfin sf 1          0
# bsmtfin sf 2          0
# bsmtfin type 1        0
# bsmtfin type 2        0
# central air           0
# condition 1           0
# condition 2           0
# electrical            0
# enclosed porch        0
# exter cond            0
# exter qual            0
# exterior 1st          0
# exterior 2nd          0
# fence              1651
# fireplace qu       1000
# fireplaces            0
# foundation            0
# full bath             0
# functional            0
# garage area           0
# garage cars           0
# garage cond           0
# garage finish         0
# garage qual           0
# garage type           0
# garage yr blt         0
# gr liv area           0
# half bath             0
# heating               0
# heating qc            0
# house style           0
# id                    0
# kitchen abvgr         0
# kitchen qual          0
# land contour          0
# land slope            0
# lot area              0
# lot config            0
# lot frontage        330
# lot shape             0
# low qual fin sf       0
# ms subclass           0
# ms zoning             0
# mas vnr area          0
# mas vnr type          0
# misc feature       1986
# misc val              0
# mo sold               0
# neighborhood          0
# open porch sf         0
# overall cond          0
# overall qual          0
# pid                   0
# paved drive           0
# pool area             0
# pool qc            2042
# roof matl             0
# roof style            0
# sale type             0
# saleprice             0
# screen porch          0
# street                0
# totrms abvgrd         0
# total bsmt sf         0
# utilities             0
# wood deck sf          0
# year built            0
# year remod/add        0
# yr sold               0
# dtype: int64

# %%
df['alley'].value_counts()   # NA is missing so replacing all NaN with NA
# Out:
# Grvl    85
# Pave    55
# Name: alley, dtype: int64

# %%
df['alley'] = df['alley'].fillna('NA') 
df_test['alley'] = df_test['alley'].fillna('NA') 
df['alley'].value_counts()
# Out:
# NA      1911
# Grvl      85
# Pave      55
# Name: alley, dtype: int64

# %%
df['fence'].value_counts()  # NA is missing so replacing all NaN with NA
# Out:
# MnPrv    227
# GdPrv     83
# GdWo      80
# MnWw      10
# Name: fence, dtype: int64

# %%
df['fence'] = df['fence'].fillna('NA') 
df_test['fence'] = df_test['fence'].fillna('NA') 
df['fence'].value_counts()
# Out:
# NA       1651
# MnPrv     227
# GdPrv      83
# GdWo       80
# MnWw       10
# Name: fence, dtype: int64

# %%
df['fireplace qu'].value_counts()  # NA is missing so replacing all NaN with NA
# Out:
# Gd    523
# TA    407
# Fa     59
# Po     31
# Ex     31
# Name: fireplace qu, dtype: int64

# %%
check_fireplaces = df[df['fireplace qu'].isnull()]
check_fireplaces['fireplaces'].value_counts()   # All 0's
# Out:
# 0    1000
# Name: fireplaces, dtype: int64

# %%
df['fireplace qu'] = df['fireplace qu'].fillna('NA') 
df_test['fireplace qu'] = df_test['fireplace qu'].fillna('NA')

# %%
df['pool qc'].value_counts() # NA is missing, checking pool area and if 0 replacing all NaN with NA
# Out:
# Gd    4
# Fa    2
# TA    2
# Ex    1
# Name: pool qc, dtype: int64

# %%
check_pools = df[df['pool qc'].isnull()]
check_pools['pool area'].value_counts()   # All 0's
# Out:
# 0    2042
# Name: pool area, dtype: int64

# %%
df['pool qc'] = df['pool qc'].fillna('NA') 
df_test['pool qc'] = df_test['pool qc'].fillna('NA')

# %%
df.isnull().sum()
# Out:
# 1st flr sf            0
# 2nd flr sf            0
# 3ssn porch            0
# alley                 0
# bedroom abvgr         0
# bldg type             0
# bsmt cond             0
# bsmt exposure         0
# bsmt full bath        0
# bsmt half bath        0
# bsmt qual             0
# bsmt unf sf           0
# bsmtfin sf 1          0
# bsmtfin sf 2          0
# bsmtfin type 1        0
# bsmtfin type 2        0
# central air           0
# condition 1           0
# condition 2           0
# electrical            0
# enclosed porch        0
# exter cond            0
# exter qual            0
# exterior 1st          0
# exterior 2nd          0
# fence                 0
# fireplace qu          0
# fireplaces            0
# foundation            0
# full bath             0
# functional            0
# garage area           0
# garage cars           0
# garage cond           0
# garage finish         0
# garage qual           0
# garage type           0
# garage yr blt         0
# gr liv area           0
# half bath             0
# heating               0
# heating qc            0
# house style           0
# id                    0
# kitchen abvgr         0
# kitchen qual          0
# land contour          0
# land slope            0
# lot area              0
# lot config            0
# lot frontage        330
# lot shape             0
# low qual fin sf       0
# ms subclass           0
# ms zoning             0
# mas vnr area          0
# mas vnr type          0
# misc feature       1986
# misc val              0
# mo sold               0
# neighborhood          0
# open porch sf         0
# overall cond          0
# overall qual          0
# pid                   0
# paved drive           0
# pool area             0
# pool qc               0
# roof matl             0
# roof style            0
# sale type             0
# saleprice             0
# screen porch          0
# street                0
# totrms abvgrd         0
# total bsmt sf         0
# utilities             0
# wood deck sf          0
# year built            0
# year remod/add        0
# yr sold               0
# dtype: int64

# %%
# lot config = Lot configuration
# lot shape = General shape of property
df['lot config'].value_counts()
# Out:
# Inside     1503
# Corner      348
# CulDSac     131
# FR2          60
# FR3           9
# Name: lot config, dtype: int64

# %%
df['lot shape'].value_counts()
# Out:
# Reg    1295
# IR1     692
# IR2      55
# IR3       9
# Name: lot shape, dtype: int64

# %%
# for each shape, or each config, there may be an average frontage we can use to approximate the missing values.  Or maybe for each shape/config combination?
df['lot frontage'].value_counts().head()
# looks like there are all rounded ot nearest foot
# Out:
# 60.00000    179
# 70.00000     96
# 80.00000     94
# 50.00000     90
# 65.00000     71
# Name: lot frontage, dtype: int64

# %%
df.groupby('lot config', as_index=False)['lot frontage'].mean()
# This makes sense
# Inside = Inside lot, I would expect to have little frontage
# Corner = Corner lot, I would expect to have more frontage than an inside lot
# CulDSac = Cul-de-sac, I would expect to have less frontage than an inside lot
# FR2 = Frontage on 2 sides of property , I would expect to have more frontage than an inside lot
# FR3 = Frontage on 3 sides of property , I would expect to have more frontage than an FR2
# Out:
#   lot config  lot frontage
# 0     Corner      83.24555
# 1    CulDSac      55.22857
# 2        FR2      60.83673
# 3        FR3      87.00000
# 4     Inside      66.95278

# %%
df.groupby('lot shape', as_index=False)['lot frontage'].mean()
# Not sure this is as useful
# Reg = Regular
# IR1 = Slightly irregular
# IR2 = Moderately Irregular
# IR3 = Irregular
# Out:
#   lot shape  lot frontage
# 0       IR1      74.58209
# 1       IR2      59.41667
# 2       IR3     115.66667
# 3       Reg      66.96860

# %%
df[df['lot config']=='Corner'].groupby('lot shape', as_index=False)['lot frontage'].mean()
# Out:
#   lot shape  lot frontage
# 0       IR1      93.30000
# 1       IR2      82.00000
# 2       IR3     224.00000
# 3       Reg      76.94149

# %%
df[df['lot config']=='Corner'].groupby('lot shape', as_index=False)['lot frontage'].count() 
# There arent many IR2 or IR3 corner lots, so taking the mean combination of config and shape probably doesnt make sense.
# Out:
#   lot shape  lot frontage
# 0       IR1            90
# 1       IR2             1
# 2       IR3             2
# 3       Reg           188

# %%
df[df['lot config']=='CulDSac'].groupby('lot shape', as_index=False)['lot frontage'].mean()   
# There isnt availabel data for Cul de sac's with all shapes
# Out:
#   lot shape  lot frontage
# 0       IR1      57.26415
# 1       IR2      49.31250
# 2       Reg      42.00000

# %%
df[df['lot config']=='CulDSac'].groupby('lot shape', as_index=False)['lot frontage'].count() 
# There arent many reg cul de sac's, so taking the mean combination of config and shape probably doesnt make sense.
# Out:
#   lot shape  lot frontage
# 0       IR1            53
# 1       IR2            16
# 2       Reg             1

# %%
# Not going to bother checking the other combinations.  We'll just use the mean by config

# %%
# find the missing lot frontage where for each config value and replace it with the mean frontage for that config value
for val in df['lot config'].unique():
    df.loc[(df['lot frontage'].isnull()) & (df['lot config'] == val), 'lot frontage'] = df[df['lot config']==val]['lot frontage'].mean()
    
for val in df_test['lot config'].unique():
    df_test.loc[(df_test['lot frontage'].isnull()) & (df_test['lot config'] == val), 'lot frontage'] = df_test[df_test['lot config']==val]['lot frontage'].mean()

# %%
df['lot frontage'].isnull().value_counts()
# Out:
# False    2051
# Name: lot frontage, dtype: int64

# %%
df.isnull().sum()
# all that is left is the misc features, per documentation it should have an NA
# going to check the Misc Val to make sure they are all 0 then replace
# Out:
# 1st flr sf            0
# 2nd flr sf            0
# 3ssn porch            0
# alley                 0
# bedroom abvgr         0
# bldg type             0
# bsmt cond             0
# bsmt exposure         0
# bsmt full bath        0
# bsmt half bath        0
# bsmt qual             0
# bsmt unf sf           0
# bsmtfin sf 1          0
# bsmtfin sf 2          0
# bsmtfin type 1        0
# bsmtfin type 2        0
# central air           0
# condition 1           0
# condition 2           0
# electrical            0
# enclosed porch        0
# exter cond            0
# exter qual            0
# exterior 1st          0
# exterior 2nd          0
# fence                 0
# fireplace qu          0
# fireplaces            0
# foundation            0
# full bath             0
# functional            0
# garage area           0
# garage cars           0
# garage cond           0
# garage finish         0
# garage qual           0
# garage type           0
# garage yr blt         0
# gr liv area           0
# half bath             0
# heating               0
# heating qc            0
# house style           0
# id                    0
# kitchen abvgr         0
# kitchen qual          0
# land contour          0
# land slope            0
# lot area              0
# lot config            0
# lot frontage          0
# lot shape             0
# low qual fin sf       0
# ms subclass           0
# ms zoning             0
# mas vnr area          0
# mas vnr type          0
# misc feature       1986
# misc val              0
# mo sold               0
# neighborhood          0
# open porch sf         0
# overall cond          0
# overall qual          0
# pid                   0
# paved drive           0
# pool area             0
# pool qc               0
# roof matl             0
# roof style            0
# sale type             0
# saleprice             0
# screen porch          0
# street                0
# totrms abvgrd         0
# total bsmt sf         0
# utilities             0
# wood deck sf          0
# year built            0
# year remod/add        0
# yr sold               0
# dtype: int64

# %%
checkl_misc = df[df['misc feature'].isnull()]
checkl_misc['misc val'].value_counts()  # all missing
# Out:
# 0    1986
# Name: misc val, dtype: int64

# %%
df['misc feature'] = df['misc feature'].fillna('NA') 
df_test['misc feature'] = df_test['misc feature'].fillna('NA')

# %%
df.isnull().sum()
# Out:
# 1st flr sf         0
# 2nd flr sf         0
# 3ssn porch         0
# alley              0
# bedroom abvgr      0
# bldg type          0
# bsmt cond          0
# bsmt exposure      0
# bsmt full bath     0
# bsmt half bath     0
# bsmt qual          0
# bsmt unf sf        0
# bsmtfin sf 1       0
# bsmtfin sf 2       0
# bsmtfin type 1     0
# bsmtfin type 2     0
# central air        0
# condition 1        0
# condition 2        0
# electrical         0
# enclosed porch     0
# exter cond         0
# exter qual         0
# exterior 1st       0
# exterior 2nd       0
# fence              0
# fireplace qu       0
# fireplaces         0
# foundation         0
# full bath          0
# functional         0
# garage area        0
# garage cars        0
# garage cond        0
# garage finish      0
# garage qual        0
# garage type        0
# garage yr blt      0
# gr liv area        0
# half bath          0
# heating            0
# heating qc         0
# house style        0
# id                 0
# kitchen abvgr      0
# kitchen qual       0
# land contour       0
# land slope         0
# lot area           0
# lot config         0
# lot frontage       0
# lot shape          0
# low qual fin sf    0
# ms subclass        0
# ms zoning          0
# mas vnr area       0
# mas vnr type       0
# misc feature       0
# misc val           0
# mo sold            0
# neighborhood       0
# open porch sf      0
# overall cond       0
# overall qual       0
# pid                0
# paved drive        0
# pool area          0
# pool qc            0
# roof matl          0
# roof style         0
# sale type          0
# saleprice          0
# screen porch       0
# street             0
# totrms abvgrd      0
# total bsmt sf      0
# utilities          0
# wood deck sf       0
# year built         0
# year remod/add     0
# yr sold            0
# dtype: int64

# %% [markdown]
# # <span style='background :#3FBFBF' >*******************  DISTRIBUTIONS *******************</span>

# %%
#with help from https://pythonexamples.org/pandas-dataframe-select-columns-of-numeric-datatype/

# df.select_dtypes(include='number')

# %%
for col in df.select_dtypes(include=np.number):
    df.hist(column=col)
# Out:
# C:\Users\benro\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:218: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)

# %% [markdown]
# # <font color='red'>**********************************************************************************************</font>
# # **************************** <span style='background :yellow' >LET'S DEAL WITH OUTLIERS</span> ****************************
# # <font color='red'>**********************************************************************************************</font>

# %%
df.agg([min,'mean',max])   # looking for potential outliers, maybe there is a better way?
#  with help from https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.agg.html
# Out:
#       1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# min    334.00000     0.00000     0.00000  Grvl        0.00000      1Fam
# mean  1164.48805   329.32911     2.59142   NaN        2.84349       NaN
# max   5095.00000  1862.00000   508.00000  Pave        8.00000    TwnhsE
#
#      bsmt cond bsmt exposure  bsmt full bath  bsmt half bath bsmt qual  \
# min         Ex            Av         0.00000         0.00000        Ex
# mean       NaN           NaN         0.42711         0.06338       NaN
# max         TA            No         3.00000         2.00000        TA
#
#       bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# min       0.00000       0.00000       0.00000            ALQ            ALQ
# mean    567.45149     442.08484      47.93564            NaN            NaN
# max    2336.00000    5644.00000    1474.00000            Unf            Unf
#
#      central air condition 1 condition 2 electrical  enclosed porch  \
# min            N      Artery      Artery      FuseA         0.00000
# mean         NaN         NaN         NaN        NaN        22.57192
# max            Y        RRNn        RRNn      SBrkr       432.00000
#
#      exter cond exter qual exterior 1st exterior 2nd  fence fireplace qu  \
# min          Ex         Ex      AsbShng      AsbShng  GdPrv           Ex
# mean        NaN        NaN          NaN          NaN    NaN          NaN
# max          TA         TA      WdShing      Wd Shng     NA           TA
#
#       fireplaces foundation  full bath functional  garage area  garage cars  \
# min      0.00000     BrkTil    0.00000       Maj1      0.00000      0.00000
# mean     0.59093        NaN    1.57728        NaN    473.44076      1.77572
# max      4.00000       Wood    4.00000        Typ   1418.00000      5.00000
#
#      garage cond garage finish garage qual garage type  gr liv area  \
# min           Ex           Fin          Ex      2Types    334.00000
# mean         NaN           NaN         NaN         NaN   1499.33008
# max           TA           Unf          TA          NA   5642.00000
#
#       half bath heating heating qc house style         id  kitchen abvgr  \
# min     0.00000    GasA         Ex      1.5Fin    1.00000        0.00000
# mean    0.37104     NaN        NaN         NaN 1474.03364        1.04291
# max     2.00000    Wall         TA        SLvl 2930.00000        3.00000
#
#      kitchen qual land contour land slope     lot area lot config  \
# min            Ex          Bnk        Gtl   1300.00000     Corner
# mean          NaN          NaN        NaN  10065.20819        NaN
# max            TA          Lvl        Sev 159000.00000     Inside
#
#       lot frontage lot shape  low qual fin sf  ms subclass ms zoning  \
# min       21.00000       IR1          0.00000     20.00000   A (agr)
# mean      68.87744       NaN          5.51292     57.00878       NaN
# max      313.00000       Reg       1064.00000    190.00000        RM
#
#       mas vnr area mas vnr type misc feature    misc val  mo sold  \
# min        0.00000       BrkCmn         Elev     0.00000  1.00000
# mean      98.62652          NaN          NaN    51.57435  6.21989
# max     1600.00000        Stone         TenC 17000.00000 12.00000
#
#      neighborhood  open porch sf  overall cond  overall qual             pid  \
# min       Blmngtn        0.00000       1.00000       1.00000 526301100.00000
# mean          NaN       47.55680       5.56216       6.11214 713590006.09166
# max       Veenker      547.00000       9.00000      10.00000 924152030.00000
#
#      paved drive  pool area pool qc roof matl roof style sale type  \
# min            N    0.00000      Ex   ClyTile       Flat       COD
# mean         NaN    2.39785     NaN       NaN        NaN       NaN
# max            Y  800.00000      TA   WdShngl       Shed       WD
#
#         saleprice  screen porch street  totrms abvgrd  total bsmt sf  \
# min   12789.00000       0.00000   Grvl        2.00000        0.00000
# mean 181469.70161      16.51146    NaN        6.43588     1057.47196
# max  611657.00000     490.00000   Pave       15.00000     6110.00000
#
#      utilities  wood deck sf  year built  year remod/add    yr sold
# min     AllPub       0.00000  1872.00000      1950.00000 2006.00000
# mean       NaN      93.83374  1971.70892      1984.19015 2007.77572
# max     NoSewr    1424.00000  2010.00000      2010.00000 2010.00000

# %%
# 1st flr sf
# bedroom abvgr
# bsmt full bath
# bsmt unf sf
# bsmtfin sf 1
# bsmtfin sf 2 - what is this?
# fireplaces
# garage area	
# gr liv area
# lot area
# lot frontage
# low qual fin sf - weird?
# mas vnr area - weird?
# open porch sf
# saleprice
# totrms abvgrd
# wood deck sf

# %%
df[df['1st flr sf']>2_400].sort_values(['1st flr sf'])  
# Only 4 above 3k sq ft
# How does this affect our saleprice?
# Do they / how do they affect our saleprice?
# Out:
#       1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 1164        2402           0           0    NA              2      1Fam
# 1647        2452           0           0    NA              3      1Fam
# 1058        2464           0           0    NA              4      1Fam
# 685         2490           0           0    NA              2      1Fam
# 623         2492           0           0    NA              2      1Fam
# 786         2497           0           0    NA              2      1Fam
# 913         2515           0           0    NA              4      1Fam
# 30          2524           0           0    NA              4      1Fam
# 1117        2633           0           0    NA              2      1Fam
# 1227        2696           0           0    NA              3      1Fam
# 952         2726           0           0    NA              2      1Fam
# 1243        2898           0           0    NA              2      1Fam
# 328         3228           0           0    NA              4      1Fam
# 616         3820           0           0    NA              5      1Fam
# 960         4692         950           0    NA              3      1Fam
# 1885        5095           0           0    NA              2      1Fam
#
#      bsmt cond bsmt exposure  bsmt full bath  bsmt half bath bsmt qual  \
# 1164        TA            Gd         1.00000         0.00000        Ex
# 1647        TA            No         2.00000         0.00000        Ex
# 1058        TA            Gd         1.00000         0.00000        Ex
# 685         TA            Gd         1.00000         0.00000        Ex
# 623         TA            Gd         1.00000         0.00000        Ex
# 786         TA            Gd         1.00000         0.00000        Gd
# 913         TA            No         1.00000         0.00000        TA
# 30          TA            No         1.00000         0.00000        Gd
# 1117        TA            Gd         1.00000         0.00000        Ex
# 1227        TA            Gd         1.00000         0.00000        Ex
# 952         TA            No         0.00000         0.00000        Gd
# 1243        TA            Av         1.00000         0.00000        Gd
# 328         TA            No         1.00000         0.00000        Gd
# 616         NA            NA         0.00000         0.00000        NA
# 960         TA            Gd         2.00000         0.00000        Ex
# 1885        TA            Gd         1.00000         1.00000        Ex
#
#       bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 1164    788.00000    1767.00000     539.00000            GLQ            ALQ
# 1647    480.00000    1972.00000       0.00000            GLQ            Unf
# 1058    195.00000    1728.00000     495.00000            GLQ            BLQ
# 685     300.00000    2158.00000       0.00000            GLQ            Unf
# 623     346.00000    2146.00000       0.00000            GLQ            Unf
# 786       0.00000    1632.00000     829.00000            ALQ            Rec
# 913     816.00000    1219.00000       0.00000            Rec            Unf
# 30     1420.00000    1104.00000       0.00000            ALQ            Unf
# 1117   1351.00000    1282.00000       0.00000            GLQ            Unf
# 1227   1473.00000    1373.00000       0.00000            GLQ            Unf
# 952     279.00000       0.00000       0.00000            Unf            Unf
# 1243      0.00000    1165.00000     400.00000            ALQ            LwQ
# 328    1969.00000    1231.00000       0.00000            GLQ            Unf
# 616       0.00000       0.00000       0.00000             NA             NA
# 960     466.00000    5644.00000       0.00000            GLQ            Unf
# 1885   1085.00000    4010.00000       0.00000            GLQ            Unf
#
#      central air condition 1 condition 2 electrical  enclosed porch  \
# 1164           Y        Norm        Norm      SBrkr               0
# 1647           Y        Norm        Norm      SBrkr               0
# 1058           Y        Norm        Norm      SBrkr               0
# 685            Y        PosN        PosN      SBrkr               0
# 623            Y        Norm        Norm      SBrkr               0
# 786            Y        Norm        Norm      SBrkr               0
# 913            Y        Norm        Norm      SBrkr             200
# 30             Y        PosN        Norm      SBrkr               0
# 1117           Y        Norm        Norm      SBrkr               0
# 1227           Y        Norm        Norm      SBrkr               0
# 952            Y        Norm        Norm      SBrkr             169
# 1243           Y        Norm        Norm      SBrkr             174
# 328            Y        Norm        Norm      SBrkr             291
# 616            Y        Norm        Norm      SBrkr               0
# 960            Y       Feedr        Norm      SBrkr               0
# 1885           Y        Norm        Norm      SBrkr               0
#
#      exter cond exter qual exterior 1st exterior 2nd  fence fireplace qu  \
# 1164         TA         Ex      VinylSd      VinylSd     NA           Gd
# 1647         TA         Gd      VinylSd      VinylSd  MnPrv           Gd
# 1058         TA         Gd      VinylSd      VinylSd     NA           Ex
# 685          TA         Ex      VinylSd      VinylSd  GdPrv           Gd
# 623          TA         Ex      CemntBd      CmentBd     NA           Ex
# 786          TA         Gd      BrkFace      BrkFace     NA           Gd
# 913          TA         Gd      Wd Sdng        Stone     NA           TA
# 30           TA         Gd      BrkFace      BrkFace  MnPrv           Gd
# 1117         TA         Ex      VinylSd      VinylSd     NA           Gd
# 1227         TA         Ex      VinylSd      VinylSd     NA           Gd
# 952          TA         Gd      WdShing      Plywood     NA           Gd
# 1243         TA         Gd        Stone      HdBoard     NA           Gd
# 328          TA         Gd      BrkFace      BrkFace     NA           Gd
# 616          TA         TA      Plywood      Plywood     NA           Gd
# 960          TA         Ex       Stucco       Stucco     NA           Gd
# 1885         TA         Ex      CemntBd      CmentBd     NA           Gd
#
#       fireplaces foundation  full bath functional  garage area  garage cars  \
# 1164           2      PConc          2        Typ    672.00000      3.00000
# 1647           1      PConc          2        Typ    886.00000      3.00000
# 1058           1      PConc          2        Typ    650.00000      3.00000
# 685            2      PConc          2        Typ    795.00000      3.00000
# 623            1      PConc          2        Typ    949.00000      3.00000
# 786            2     CBlock          2        Typ    676.00000      2.00000
# 913            2      PConc          3       Maj1    484.00000      2.00000
# 30             1      PConc          2        Typ    542.00000      2.00000
# 1117           2      PConc          2        Typ    804.00000      3.00000
# 1227           2      PConc          2        Typ    958.00000      3.00000
# 952            1     CBlock          2        Typ    691.00000      2.00000
# 1243           1     CBlock          2        Typ    665.00000      2.00000
# 328            1      PConc          3        Typ    546.00000      2.00000
# 616            2       Slab          3        Typ    624.00000      2.00000
# 960            3      PConc          2        Typ   1418.00000      2.00000
# 1885           2      PConc          2        Typ   1154.00000      3.00000
#
#      garage cond garage finish garage qual garage type garage yr blt  \
# 1164          TA           Fin          TA      Attchd    2008.00000
# 1647          TA           Fin          TA      Attchd    2003.00000
# 1058          TA           Fin          TA      Attchd    2007.00000
# 685           TA           Fin          TA      Attchd    2005.00000
# 623           TA           Fin          TA      Attchd    2004.00000
# 786           TA           RFn          TA      Attchd    1981.00000
# 913           TA           RFn          TA      Attchd    1975.00000
# 30            TA           Fin          TA      Attchd    1981.00000
# 1117          TA           RFn          TA      Attchd    2001.00000
# 1227          TA           Fin          TA      Attchd    2003.00000
# 952           Gd           Fin          Gd      Attchd    1986.00000
# 1243          TA           Fin          TA      Attchd    1976.00000
# 328           TA           RFn          TA      Attchd    1992.00000
# 616           TA           Unf          TA      Attchd    1959.00000
# 960           TA           Fin          TA      Attchd    2008.00000
# 1885          TA           Fin          TA      Attchd    2008.00000
#
#       gr liv area  half bath heating heating qc house style    id  \
# 1164         2402          0    GasA         Ex      1Story   424
# 1647         2452          0    GasA         Ex      1Story   449
# 1058         2464          1    GasA         Ex      1Story  1057
# 685          2490          0    GasA         Ex      1Story   514
# 623          2492          1    GasA         Ex      1Story   457
# 786          2497          0    GasA         Gd      1Story  1861
# 913          2515          0    GasA         TA      1Story  2230
# 30           2524          1    GasA         TA      1Story   380
# 1117         2633          1    GasA         Ex      1Story  1764
# 1227         2696          1    GasA         Ex      1Story    47
# 952          2726          1    GasA         Gd      1Story  2231
# 1243         2898          0    GasA         TA      1Story  1573
# 328          3228          0    GasA         Ex      1Story  1773
# 616          3820          1    GasA         TA      1Story  1498
# 960          5642          1    GasA         Ex      2Story  1499
# 1885         5095          1    GasA         Ex      1Story  2181
#
#       kitchen abvgr kitchen qual land contour land slope  lot area lot config  \
# 1164              1           Ex          Lvl        Gtl     15431     Inside
# 1647              1           Ex          Lvl        Gtl     15274     Corner
# 1058              1           Ex          Lvl        Gtl     13693     Inside
# 685               1           Ex          Lvl        Gtl     11128     Corner
# 623               1           Ex          HLS        Mod     14836     Inside
# 786               1           Gd          Lvl        Gtl     17778     Inside
# 913               2           TA          Lvl        Gtl     32668    CulDSac
# 30                1           Gd          Lvl        Gtl      9600     Inside
# 1117              1           Ex          Lvl        Gtl     11400     Inside
# 1227              1           Ex          HLS        Mod     14300     Inside
# 952               1           Gd          HLS        Gtl     18044    CulDSac
# 1243              1           Gd          Lvl        Gtl     15498     Corner
# 328               1           Gd          Lvl        Gtl     12692     Inside
# 616               1           Ex          Lvl        Gtl     47007     Inside
# 960               1           Ex          Bnk        Gtl     63887     Corner
# 1885              1           Ex          Bnk        Gtl     39290     Inside
#
#       lot frontage lot shape  low qual fin sf  ms subclass ms zoning  \
# 1164     105.00000       Reg                0           20        RL
# 1647     110.00000       IR1                0           20        RL
# 1058     105.00000       Reg                0           20        RL
# 685       85.00000       Reg                0           20        RL
# 623      100.00000       IR1                0           20        RL
# 786       94.00000       IR1                0           20        RL
# 913       55.22857       IR1                0           20        RL
# 30        80.00000       Reg                0           20        RL
# 1117      66.95278       Reg                0           20        RL
# 1227     110.00000       Reg                0           20        RL
# 952       70.00000       IR1                0           20        RL
# 1243      83.24555       IR1                0           20        RL
# 328       66.95278       IR1                0           20        RL
# 616      123.00000       IR1                0           20        RL
# 960      313.00000       IR3                0           60        RL
# 1885     128.00000       IR1                0           20        RL
#
#       mas vnr area mas vnr type misc feature  misc val  mo sold neighborhood  \
# 1164     200.00000        Stone           NA         0        4      NridgHt
# 1647     724.00000      BrkFace           NA         0        7      NridgHt
# 1058     554.00000        Stone           NA         0        8      NridgHt
# 685      198.00000        Stone           NA         0       10      Somerst
# 623      730.00000        Stone           NA         0        2      NridgHt
# 786        0.00000         None           NA         0        3      Veenker
# 913        0.00000         None           NA         0        3      Crawfor
# 30         0.00000         None           NA         0        7       NWAmes
# 1117     705.00000      BrkFace           NA         0        3      NoRidge
# 1227    1095.00000      BrkFace           NA         0        6      NridgHt
# 952        0.00000         None           NA         0        8      Crawfor
# 1243       0.00000         None           NA         0        5       Timber
# 328        0.00000         None           NA         0        5      NoRidge
# 616        0.00000         None           NA         0        7      Edwards
# 960      796.00000        Stone           NA         0        1      Edwards
# 1885    1224.00000        Stone         Elev     17000       10      Edwards
#
#       open porch sf  overall cond  overall qual        pid paved drive  \
# 1164             72             5            10  528106020           Y
# 1647            116             5             9  528166090           Y
# 1058             78             5             8  528110110           Y
# 685             226             5             9  528441090           Y
# 623             235             5            10  528176030           Y
# 786               0             5             8  533350020           Y
# 913               0             3             6  909475070           Y
# 30              120             5             8  527355150           Y
# 1117            140             5            10  528327060           Y
# 1227            150             5             9  528176010           Y
# 952              64             5             8  909475230           Y
# 1243             72             6             8  916325080           Y
# 328              75             5             8  528366050           Y
# 616             372             7             5  908154080           Y
# 960             292             5            10  908154235           Y
# 1885            484             5            10  908154195           Y
#
#       pool area pool qc roof matl roof style sale type  saleprice  \
# 1164          0      NA   CompShg        Hip       WD      555000
# 1647          0      NA   CompShg        Hip       WD      445000
# 1058          0      NA   CompShg        Hip       WD      417500
# 685           0      NA   CompShg        Hip       WD      468000
# 623           0      NA   CompShg        Hip       WD      552000
# 786           0      NA   CompShg        Hip       WD      373000
# 913           0      NA   CompShg        Hip       WD      200624
# 30            0      NA   WdShngl        Hip       WD      278000
# 1117          0      NA   CompShg        Hip       WD      466500
# 1227          0      NA   CompShg        Hip       WD      500000
# 952         228      Ex   CompShg      Gable       WD      315000
# 1243          0      NA   WdShake        Hip       COD     287000
# 328           0      NA   CompShg        Hip       WD      430000
# 616           0      NA   CompShg      Gable       WD      284700
# 960         480      Gd   ClyTile        Hip       New     160000
# 1885          0      NA   CompShg        Hip       New     183850
#
#       screen porch street  totrms abvgrd  total bsmt sf utilities  \
# 1164           170   Pave             10     3094.00000    AllPub
# 1647             0   Pave             10     2452.00000    AllPub
# 1058             0   Pave              9     2418.00000    AllPub
# 685              0   Pave              9     2458.00000    AllPub
# 623              0   Pave              8     2492.00000    AllPub
# 786              0   Pave              7     2461.00000    AllPub
# 913              0   Pave              9     2035.00000    AllPub
# 30               0   Pave              9     2524.00000    AllPub
# 1117             0   Pave              8     2633.00000    AllPub
# 1227             0   Pave             10     2846.00000    AllPub
# 952              0   Pave              6      279.00000    AllPub
# 1243             0   Pave             10     1565.00000    AllPub
# 328              0   Pave             10     3200.00000    AllPub
# 616              0   Pave             11        0.00000    AllPub
# 960              0   Pave             12     6110.00000    AllPub
# 1885             0   Pave             15     5095.00000    AllPub
#
#       wood deck sf  year built  year remod/add  yr sold
# 1164             0        2008            2008     2009
# 1647             0        2003            2003     2009
# 1058           358        2007            2007     2008
# 685             70        2005            2006     2009
# 623            226        2004            2005     2009
# 786            266        1981            1981     2007
# 913              0        1957            1975     2007
# 30             474        1981            1981     2009
# 1117           314        2001            2002     2007
# 1227           220        2003            2004     2010
# 952            216        1986            1986     2007
# 1243             0        1976            1976     2008
# 328            264        1992            1993     2007
# 616              0        1959            1996     2008
# 960            214        2008            2008     2008
# 1885           546        2008            2009     2007

# %%
sns.boxplot(x=df['1st flr sf']) ; 
# The shows a lot of outliers, but I dont know if I need ot get rid of them?

# %%
sns.jointplot(x=df['1st flr sf'],y=df['saleprice'],
              kind="reg",
              #scatter_kws={'color':'orange','alpha':0.77}
              line_kws={'color':'red','alpha':0.77}
              );
# This is super cool! https://ajaytech.co/2020/09/28/8780/
# with help from https://stackoverflow.com/questions/48145924/different-colors-for-points-and-line-in-seaborn-regplot

# %%
df[df['bedroom abvgr']>6].sort_values(['bedroom abvgr'])  
# 5 and 6 isnt unusual.  There is one with 8 bedrooms.  Index # 858
# Does the one / how does the one affect our saleprice?
# Out:
#      1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 858        1440        1440           0  Pave              8    2fmCon
#
#     bsmt cond bsmt exposure  bsmt full bath  bsmt half bath bsmt qual  \
# 858        Fa            No         0.00000         0.00000        TA
#
#      bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 858   1184.00000     256.00000       0.00000            LwQ            Unf
#
#     central air condition 1 condition 2 electrical  enclosed porch exter cond  \
# 858           Y       Feedr        Norm      FuseA               0         TA
#
#     exter qual exterior 1st exterior 2nd fence fireplace qu  fireplaces  \
# 858         Fa      VinylSd      VinylSd    NA           NA           0
#
#     foundation  full bath functional  garage area  garage cars garage cond  \
# 858     CBlock          2        Typ      0.00000      0.00000          NA
#
#     garage finish garage qual garage type garage yr blt  gr liv area  \
# 858            NA          NA          NA            NA         3395
#
#      half bath heating heating qc house style    id  kitchen abvgr  \
# 858          0    GasA         Ex      2.5Fin  2195              2
#
#     kitchen qual land contour land slope  lot area lot config  lot frontage  \
# 858           Fa          Bnk        Gtl     10896     Inside      60.00000
#
#     lot shape  low qual fin sf  ms subclass ms zoning  mas vnr area  \
# 858       Reg              515          190        RH       0.00000
#
#     mas vnr type misc feature  misc val  mo sold neighborhood  open porch sf  \
# 858         None           NA         0        3        SWISU            110
#
#      overall cond  overall qual        pid paved drive  pool area pool qc  \
# 858             7             6  909176080           N          0      NA
#
#     roof matl roof style sale type  saleprice  screen porch street  \
# 858   CompShg        Hip       WD      200000             0   Pave
#
#      totrms abvgrd  total bsmt sf utilities  wood deck sf  year built  \
# 858             14     1440.00000    AllPub             0        1914
#
#      year remod/add  yr sold
# 858            1995     2007

# %%
df[df['bsmt full bath']>2].sort_values(['bsmt full bath'])
# 2 isnt unusual.  There are two with 3 fulls baths
# Does this / how does this affect our saleprice?
# Out:
#       1st flr sf  2nd flr sf  3ssn porch alley  bedroom abvgr bldg type  \
# 791         1200           0           0    NA              3    Duplex
# 1584        1200           0           0    NA              3    Duplex
#
#      bsmt cond bsmt exposure  bsmt full bath  bsmt half bath bsmt qual  \
# 791         Gd            Gd         3.00000         0.00000        Gd
# 1584        Gd            Gd         3.00000         0.00000        Gd
#
#       bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 791       0.00000    1200.00000       0.00000            GLQ            Unf
# 1584      0.00000    1200.00000       0.00000            GLQ            Unf
#
#      central air condition 1 condition 2 electrical  enclosed porch  \
# 791            Y        Norm        Norm      SBrkr               0
# 1584           Y        Norm        Norm      SBrkr               0
#
#      exter cond exter qual exterior 1st exterior 2nd fence fireplace qu  \
# 791          TA         TA      Plywood      Plywood    NA           NA
# 1584         Gd         TA      Plywood      Plywood    NA           NA
#
#       fireplaces foundation  full bath functional  garage area  garage cars  \
# 791            0     CBlock          3        Typ      0.00000      0.00000
# 1584           0     CBlock          3        Typ      0.00000      0.00000
#
#      garage cond garage finish garage qual garage type garage yr blt  \
# 791           NA            NA          NA          NA            NA
# 1584          NA            NA          NA          NA            NA
#
#       gr liv area  half bath heating heating qc house style   id  \
# 791          1200          0    GasA         TA      1Story  763
# 1584         1200          0    GasA         TA      1Story  764
#
#       kitchen abvgr kitchen qual land contour land slope  lot area lot config  \
# 791               1           TA          Lvl        Gtl     10800     Inside
# 1584              1           TA          Lvl        Gtl     10800     Inside
#
#       lot frontage lot shape  low qual fin sf  ms subclass ms zoning  \
# 791       60.00000       Reg                0           90        RL
# 1584      60.00000       Reg                0           90        RL
#
#       mas vnr area mas vnr type misc feature  misc val  mo sold neighborhood  \
# 791        0.00000         None           NA         0        3      Edwards
# 1584       0.00000         None           NA         0        3      Edwards
#
#       open porch sf  overall cond  overall qual        pid paved drive  \
# 791               0             5             5  904301060           Y
# 1584              0             5             5  904301070           Y
#
#       pool area pool qc roof matl roof style sale type  saleprice  \
# 791           0      NA   CompShg      Gable       WD      179000
# 1584          0      NA   CompShg      Gable       WD      179000
#
#       screen porch street  totrms abvgrd  total bsmt sf utilities  \
# 791              0   Pave              5     1200.00000    AllPub
# 1584             0   Pave              5     1200.00000    AllPub
#
#       wood deck sf  year built  year remod/add  yr sold
# 791            120        1987            1988     2009
# 1584           120        1987            1988     2009

# %%
sns.boxplot(x=df['lot frontage']) ;  # Looks like there are some above 300, this isnt terribly helpful since I dont know the effect of the outlier on the sales price

# %% [markdown]
# # <font color='red'>**********************************************************************************************</font>
# # **************************** <span style='background :yellow' >NON NUMERIC CLEANUP</span> ****************************
# # <font color='red'>**********************************************************************************************</font>

# %%
# Looking at the documentation, we can binarize 'Street' and 'Central Air'

# %%
df['street'].value_counts()
# Out:
# Pave    2044
# Grvl       7
# Name: street, dtype: int64

# %%
df['central air'].value_counts()
# Out:
# Y    1910
# N     141
# Name: central air, dtype: int64

# %%
df['street'] = df['street'].map({'Pave':1, 'Grvl':0})
df_test['street'] = df_test['street'].map({'Pave':1, 'Grvl':0})

# %%
df['central air'] = df['central air'].map({'Y':1, 'N':0})
df_test['central air'] = df_test['central air'].map({'Y':1, 'N':0})

# %%
df['street'].value_counts()
# Out:
# 1    2044
# 0       7
# Name: street, dtype: int64

# %%
df['central air'].value_counts()
# Out:
# 1    1910
# 0     141
# Name: central air, dtype: int64

# %%
df.isnull().sum()
# Out:
# 1st flr sf         0
# 2nd flr sf         0
# 3ssn porch         0
# alley              0
# bedroom abvgr      0
# bldg type          0
# bsmt cond          0
# bsmt exposure      0
# bsmt full bath     0
# bsmt half bath     0
# bsmt qual          0
# bsmt unf sf        0
# bsmtfin sf 1       0
# bsmtfin sf 2       0
# bsmtfin type 1     0
# bsmtfin type 2     0
# central air        0
# condition 1        0
# condition 2        0
# electrical         0
# enclosed porch     0
# exter cond         0
# exter qual         0
# exterior 1st       0
# exterior 2nd       0
# fence              0
# fireplace qu       0
# fireplaces         0
# foundation         0
# full bath          0
# functional         0
# garage area        0
# garage cars        0
# garage cond        0
# garage finish      0
# garage qual        0
# garage type        0
# garage yr blt      0
# gr liv area        0
# half bath          0
# heating            0
# heating qc         0
# house style        0
# id                 0
# kitchen abvgr      0
# kitchen qual       0
# land contour       0
# land slope         0
# lot area           0
# lot config         0
# lot frontage       0
# lot shape          0
# low qual fin sf    0
# ms subclass        0
# ms zoning          0
# mas vnr area       0
# mas vnr type       0
# misc feature       0
# misc val           0
# mo sold            0
# neighborhood       0
# open porch sf      0
# overall cond       0
# overall qual       0
# pid                0
# paved drive        0
# pool area          0
# pool qc            0
# roof matl          0
# roof style         0
# sale type          0
# saleprice          0
# screen porch       0
# street             0
# totrms abvgrd      0
# total bsmt sf      0
# utilities          0
# wood deck sf       0
# year built         0
# year remod/add     0
# yr sold            0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# 1st flr sf           0
# 2nd flr sf           0
# 3ssn porch           0
# alley                0
# bedroom abvgr        0
# bldg type            0
# bsmt cond            0
# bsmt exposure        0
# bsmt full bath       0
# bsmt half bath       0
# bsmt qual            0
# bsmt unf sf          0
# bsmtfin sf 1         0
# bsmtfin sf 2         0
# bsmtfin type 1       0
# bsmtfin type 2       0
# central air          0
# condition 1          0
# condition 2          0
# electrical           1
# enclosed porch       0
# exter cond           0
# exter qual           0
# exterior 1st         0
# exterior 2nd         0
# fence                0
# fireplace qu         0
# fireplaces           0
# foundation           0
# full bath            0
# functional           0
# garage area          0
# garage cars          0
# garage cond          0
# garage finish        0
# garage qual          0
# garage type          0
# garage yr blt        0
# gr liv area          0
# half bath            0
# heating              0
# heating qc           0
# house style          0
# id                   0
# kitchen abvgr        0
# kitchen qual         0
# land contour         0
# land slope           0
# lot area             0
# lot config           0
# lot frontage         0
# lot shape            0
# low qual fin sf      0
# ms subclass          0
# ms zoning            0
# mas vnr area         0
# mas vnr type         0
# misc feature         0
# misc val             0
# mo sold              0
# neighborhood         0
# open porch sf        0
# overall cond         0
# overall qual         0
# pid                  0
# paved drive          0
# pool area            0
# pool qc              0
# roof matl            0
# roof style           0
# sale type            0
# saleprice          878
# screen porch         0
# street               0
# totrms abvgrd        0
# total bsmt sf        0
# utilities            0
# wood deck sf         0
# year built           0
# year remod/add       0
# yr sold              0
# dtype: int64

# %%
df_test['electrical'] = df_test['electrical'].fillna(0)

# %%
####****************************************************************************######

# %%
obj_cols = df.dtypes[df.dtypes == 'object'].index
obj_cols
# Out:
# Index(['alley', 'bldg type', 'bsmt cond', 'bsmt exposure', 'bsmt qual',
#        'bsmtfin type 1', 'bsmtfin type 2', 'condition 1', 'condition 2',
#        'electrical', 'exter cond', 'exter qual', 'exterior 1st',
#        'exterior 2nd', 'fence', 'fireplace qu', 'foundation', 'functional',
#        'garage cond', 'garage finish', 'garage qual', 'garage type',
#        'garage yr blt', 'heating', 'heating qc', 'house style', 'kitchen qual',
#        'land contour', 'land slope', 'lot config', 'lot shape', 'ms zoning',
#        'mas vnr type', 'misc feature', 'neighborhood', 'paved drive',
#        'pool qc', 'roof matl', 'roof style', 'sale type', 'utilities'],
#       dtype='object')

# %%
# accoring to documentation, these columns are ordinal. So we should be able to assign meaningful values where they aren't already numeric
# Lot Shape, Utilities, Land Slope, Overall Qual (num), Overall Cond(num), Exter Qual, Exter Cond, Bsmt Qual, 
# Bsmt Cond, Bsmt Exposure, BsmtFin Type 1,BsmtFinType 2, HeatingQC, Electrical, KitchenQual, Functional, FireplaceQu, 
# Garage Finish, Garage Qual, Garage Cond, Paved Drive, Pool QC, Fence 

# it looks like Fireplace Qu, Garage Qual, Garage Cond,  Pool QC, Fence all use the same scale
# so do BsmtFin Type 1, and BsmtFinType 2
# so do Exter Qual, Exter Cond, KitchenQual
# so do Bsmt Qual, Bsmt Cond

# %%
df['fireplace qu'].value_counts()
# Out:
# NA    1000
# Gd     523
# TA     407
# Fa      59
# Po      31
# Ex      31
# Name: fireplace qu, dtype: int64

# %%
fix_dict_1 = {'Ex': 5,'Gd': 4,'TA': 3,'Fa': 2,'Po': 1,'NA': 0} # create a dictionary of the values in the data and the numeric values you want them to have
cols_to_fix1 = ['fireplace qu','garage qual','garage cond','pool qc']  # create a list of the columns to fix

# %%
for col in cols_to_fix1:
    df[col] = df[col].replace(fix_dict_1)
    df_test[col] = df_test[col].replace(fix_dict_1)

# %%
df['bsmtfin type 1'].value_counts()
# Out:
# GLQ    615
# Unf    603
# ALQ    293
# BLQ    200
# Rec    183
# LwQ    102
# NA      55
# Name: bsmtfin type 1, dtype: int64

# %%
fix_dict_2 = {'GLQ':6,'ALQ':5,'BLQ':4,'Rec':3,'LwQ':2,'Unf':1} # create a dictionary of the values in the data and the numeric values you want them to have
cols_to_fix2 = ['bsmtfin type 1','bsmtfin type 2']  # create a list of the columns to fix

# %%
for col in cols_to_fix2:
    df[col] = df[col].replace(fix_dict_2)
    df_test[col] = df_test[col].replace(fix_dict_2)

# %%
fix_dict_3 = {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1} # create a dictionary of the values in the data and the numeric values you want them to have
cols_to_fix3 = ['exter qual','exter cond','kitchen qual','heating qc']  # create a list of the columns to fix

# %%
for col in cols_to_fix3:
    df[col] = df[col].replace(fix_dict_3)
    df_test[col] = df_test[col].replace(fix_dict_3)

# %%
fix_dict_4 = {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NA':0} # create a dictionary of the values in the data and the numeric values you want them to have
cols_to_fix4 = ['bsmt qual', 'bsmt cond']  # create a list of the columns to fix

# %%
for col in cols_to_fix4:
    df[col] = df[col].replace(fix_dict_4)
    df_test[col] = df_test[col].replace(fix_dict_4)

# %%
###  all of the rest are on different scales, so we could throw them all in one dictionary and then use the one big dictionary to update the remaining columns

# %%
fix_dict_5= {
    #lot shape
    'Reg':4,
    'IR1':3,
    'IR2':2,
    'IR3':1,
#garage finish    
    'Fin':3,
    'RFn':2,
    'Unf':1,
    'NA':0,
#utilities
    'AllPub':4,
    'NoSewr':3,
    'NoSeWa':2,
    'ELO':1,   
#land slope
    'Gtl':3,
    'Mod':2,
    'Sev':1,
#paved drive
    'Y' : 2,
    'P' : 1,
    'N' : 0,
#electrical
    'SBrkr':5,
    'FuseA':4,
    'FuseF':3,
    'FuseP':2,
    'Mix':1,
#fence
    'GdPrv':4,
    'MnPrv':3,
    'GdWo':2,
    'MnWw':1,
#functional
    'Typ':8,
    'Min1':7,
    'Min2':6,
    'Mod':5,
    'Maj1':4,
    'Maj2':3,
    'Sev':2,
    'Sal':1,
#garage finish    
    'Gd':3,
    'Av':3,
    'Mn':2,
    'No':1,
    'NA':0,
}

# %%
cols_to_fix5 = ['lot shape','garage finish','utilities','land slope','paved drive','electrical','fence','functional', 'bsmt exposure']  # create a list of the columns to fix

# %%
for col in cols_to_fix5:
    df[col] = df[col].replace(fix_dict_5)
    df_test[col] = df_test[col].replace(fix_dict_5)

# %%
########################******************************************************########################
########################******************************************************########################
########################******************************************************########################
# Before creating dummies for each remaining columns, let's make sure that all available options are 
# on both sets of data, figure out what to do if something is missing from one set or the other
# and make sure that we need to create so many additional columns
########################******************************************************########################
########################******************************************************########################
########################******************************************************########################

# %%
print(df['alley'].value_counts()),
print(df_test['alley'].value_counts())
# Looks like they have the same values
# Out:
# NA      1911
# Grvl      85
# Pave      55
# Name: alley, dtype: int64
# NA      820
# Grvl     35
# Pave     23
# Name: alley, dtype: int64

# %%
df_td = df   #set df_td = df, then put in to numeric categories and look for correlation

fix_dict_alley = {'Grvl':2,'Pave':1,'NA':0} # create a dictionary of the values in the data and the numeric values you want them to have
df['alley'] = df['alley'].replace(fix_dict_alley)
df_test['alley'] = df_test['alley'].replace(fix_dict_alley)

# %%
sns.jointplot(x=df_td['alley'],y=df_td['saleprice'],
              kind="reg",
              );
# This is super cool! https://ajaytech.co/2020/09/28/8780/
# Looks like Gravel alleys VS Paved alleys could have a small affect on sale price
# creating dummies

# %%
print(df['bldg type'].value_counts()),
print(df_test['bldg type'].value_counts())
# Looks like they have the same values
# but the documentation says that "Twnhs" should probably be "TwnhsI"
# Out:
# 1Fam      1700
# TwnhsE     161
# Duplex      75
# Twnhs       69
# 2fmCon      46
# Name: bldg type, dtype: int64
# 1Fam      724
# TwnhsE     72
# Duplex     34
# Twnhs      32
# 2fmCon     16
# Name: bldg type, dtype: int64

# %%
df_td = df   #set df_td = df, then put in to numeric categories and look for correlation

fix_dict_bldg_type = {'1Fam':5,'TwnhsE':4,'Duplex':3,'Twnhs':2,'2fmCon':1} # create a dictionary of the values in the data and the numeric values you want them to have
# df_td['bldg type'] = df['bldg type'].replace(fix_dict_bldg_type)

# sns.jointplot(x=df_td['bldg type'],y=df_td['saleprice'],
#               kind="reg",
#               );
# # Looks like there is some affect on slaeprice, creting dummie

# %%
df.head()
# Out:
#    1st flr sf  2nd flr sf  3ssn porch  alley  bedroom abvgr bldg type  \
# 0         725         754           0      0              3      1Fam
# 1         913        1209           0      0              4      1Fam
# 2        1057           0           0      0              3      1Fam
# 3         744         700           0      0              3      1Fam
# 4         831         614           0      0              3      1Fam
#
#    bsmt cond  bsmt exposure  bsmt full bath  bsmt half bath  bsmt qual  \
# 0          3              1         0.00000         0.00000          3
# 1          3              1         1.00000         0.00000          4
# 2          3              1         1.00000         0.00000          3
# 3          3              1         0.00000         0.00000          4
# 4          4              1         0.00000         0.00000          2
#
#    bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 0    192.00000     533.00000       0.00000              6              1
# 1    276.00000     637.00000       0.00000              6              1
# 2    326.00000     731.00000       0.00000              6              1
# 3    384.00000       0.00000       0.00000              1              1
# 4    676.00000       0.00000       0.00000              1              1
#
#    central air condition 1 condition 2  electrical  enclosed porch  \
# 0            1        RRAe        Norm           5               0
# 1            1        Norm        Norm           5               0
# 2            1        Norm        Norm           5               0
# 3            1        Norm        Norm           5               0
# 4            1        Norm        Norm           5               0
#
#    exter cond  exter qual exterior 1st exterior 2nd  fence  fireplace qu  \
# 0           3           4      HdBoard      Plywood      0             0
# 1           3           4      VinylSd      VinylSd      0             3
# 2           4           3      VinylSd      VinylSd      0             0
# 3           3           3      VinylSd      VinylSd      0             0
# 4           3           3      Wd Sdng      Plywood      0             0
#
#    fireplaces foundation  full bath  functional  garage area  garage cars  \
# 0           0     CBlock          2           8    475.00000      2.00000
# 1           1      PConc          2           8    559.00000      2.00000
# 2           0     CBlock          1           8    246.00000      1.00000
# 3           0      PConc          2           8    400.00000      2.00000
# 4           0      PConc          2           8    484.00000      2.00000
#
#    garage cond  garage finish  garage qual garage type garage yr blt  \
# 0            3              2            3      Attchd    1976.00000
# 1            3              2            3      Attchd    1997.00000
# 2            3              1            3      Detchd    1953.00000
# 3            3              3            3     BuiltIn    2007.00000
# 4            3              1            3      Detchd    1957.00000
#
#    gr liv area  half bath heating  heating qc house style   id  kitchen abvgr  \
# 0         1479          1    GasA           5      2Story  109              1
# 1         2122          1    GasA           5      2Story  544              1
# 2         1057          0    GasA           3      1Story  153              1
# 3         1444          1    GasA           4      2Story  318              1
# 4         1445          0    GasA           3      1.5Fin  255              1
#
#    kitchen qual land contour  land slope  lot area lot config  lot frontage  \
# 0             4          Lvl           3     13517    CulDSac      55.22857
# 1             4          Lvl           3     11492    CulDSac      43.00000
# 2             4          Lvl           3      7922     Inside      68.00000
# 3             3          Lvl           3      9802     Inside      73.00000
# 4             3          Lvl           3     14235     Inside      82.00000
#
#    lot shape  low qual fin sf  ms subclass ms zoning  mas vnr area  \
# 0          3                0           60        RL     289.00000
# 1          3                0           60        RL     132.00000
# 2          4                0           20        RL       0.00000
# 3          4                0           60        RL       0.00000
# 4          3                0           50        RL       0.00000
#
#   mas vnr type misc feature  misc val  mo sold neighborhood  open porch sf  \
# 0      BrkFace           NA         0        3       Sawyer             44
# 1      BrkFace           NA         0        4      SawyerW             74
# 2         None           NA         0        1        NAmes             52
# 3         None           NA         0        4       Timber              0
# 4         None           NA         0        3      SawyerW             59
#
#    overall cond  overall qual        pid  paved drive  pool area  pool qc  \
# 0             8             6  533352170            2          0        0
# 1             5             7  531379050            2          0        0
# 2             7             5  535304180            2          0        0
# 3             5             5  916386060            2          0        0
# 4             8             6  906425045            0          0        0
#
#   roof matl roof style sale type  saleprice  screen porch  street  \
# 0   CompShg      Gable       WD      130500             0       1
# 1   CompShg      Gable       WD      220000             0       1
# 2   CompShg      Gable       WD      109000             0       1
# 3   CompShg      Gable       WD      174000             0       1
# 4   CompShg      Gable       WD      138500             0       1
#
#    totrms abvgrd  total bsmt sf  utilities  wood deck sf  year built  \
# 0              6      725.00000          4             0        1976
# 1              8      913.00000          4             0        1996
# 2              5     1057.00000          4             0        1953
# 3              7      384.00000          4           100        2006
# 4              6      676.00000          4             0        1900
#
#    year remod/add  yr sold
# 0            2005     2010
# 1            1997     2009
# 2            2007     2010
# 3            2007     2010
# 4            1993     2010

# %%
df_test.head()
# Out:
#    1st flr sf  2nd flr sf  3ssn porch  alley  bedroom abvgr bldg type  \
# 0         908        1020           0      2              4    2fmCon
# 1        1967           0           0      0              6    Duplex
# 2         664         832           0      0              3      1Fam
# 3         968           0           0      0              2      1Fam
# 4        1394           0           0      0              3      1Fam
#
#    bsmt cond  bsmt exposure  bsmt full bath  bsmt half bath  bsmt qual  \
# 0          3              1               0               0          2
# 1          3              1               0               0          4
# 2          4              3               1               0          4
# 3          3              1               0               0          3
# 4          3              1               1               0          4
#
#    bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 0         1020             0             0              1              1
# 1         1967             0             0              1              1
# 2          100           554             0              6              1
# 3          968             0             0              1              1
# 4          785           609             0              4              1
#
#    central air condition 1 condition 2  electrical  enclosed porch  \
# 0            0        Norm        Norm           2             112
# 1            1        Norm        Norm           5               0
# 2            1        Norm        Norm           5               0
# 3            1        Norm        Norm           5             184
# 4            1        Norm        Norm           5               0
#
#    exter cond  exter qual exterior 1st exterior 2nd  fence  fireplace qu  \
# 0           2           3      AsbShng      AsbShng      0             0
# 1           3           3      Plywood      Plywood      0             0
# 2           3           4      VinylSd      VinylSd      0             4
# 3           3           4      Wd Sdng      Wd Sdng      0             0
# 4           3           3      Plywood      Plywood      0             4
#
#    fireplaces foundation  full bath  functional  garage area  garage cars  \
# 0           0      Stone          2           8          440            1
# 1           0     CBlock          2           8          580            2
# 2           1      PConc          2           8          426            2
# 3           0     CBlock          1           8          480            2
# 4           2     CBlock          1           8          514            2
#
#    garage cond  garage finish  garage qual garage type garage yr blt  \
# 0            1              1            1      Detchd    1910.00000
# 1            3              3            3      Attchd    1977.00000
# 2            3              2            3      Attchd    2006.00000
# 3            3              1            2      Detchd    1935.00000
# 4            3              2            3      Attchd    1963.00000
#
#    gr liv area  half bath heating  heating qc house style    id  \
# 0         1928          0    GasA           4      2Story  2658
# 1         1967          0    GasA           3      1Story  2718
# 2         1496          1    GasA           5      2Story  2414
# 3          968          0    GasA           3      1Story  1989
# 4         1394          1    GasA           4      1Story   625
#
#    kitchen abvgr  kitchen qual land contour  land slope  lot area lot config  \
# 0              2             2          Lvl           3      9142     Inside
# 1              2             3          Lvl           3      9662     Inside
# 2              1             4          Lvl           3     17104     Inside
# 3              1             3          Lvl           3      8520     Inside
# 4              1             3          Lvl           3      9500     Inside
#
#    lot frontage  lot shape  low qual fin sf  ms subclass ms zoning  \
# 0      69.00000          4                0          190        RM
# 1      67.49638          3                0           90        RL
# 2      58.00000          3                0           60        RL
# 3      60.00000          4                0           30        RM
# 4      67.49638          3                0           20        RL
#
#    mas vnr area mas vnr type misc feature  misc val  mo sold neighborhood  \
# 0       0.00000         None           NA         0        4      OldTown
# 1       0.00000         None           NA         0        8       Sawyer
# 2       0.00000         None           NA         0        9      Gilbert
# 3       0.00000         None           NA         0        7      OldTown
# 4     247.00000      BrkFace           NA         0        7        NAmes
#
#    open porch sf  overall cond  overall qual        pid  paved drive  \
# 0             60             8             6  902301120            2
# 1              0             4             5  905108090            2
# 2             24             5             7  528218130            2
# 3              0             6             5  902207150            0
# 4             76             5             6  535105100            2
#
#    pool area  pool qc roof matl roof style sale type  saleprice  screen porch  \
# 0          0        0   CompShg      Gable       WD         NaN             0
# 1          0        0   CompShg      Gable       WD         NaN             0
# 2          0        0   CompShg      Gable       New        NaN             0
# 3          0        0   CompShg      Gable       WD         NaN             0
# 4          0        0   CompShg      Gable       WD         NaN           185
#
#    street  totrms abvgrd  total bsmt sf  utilities  wood deck sf  year built  \
# 0       1              9           1020          4             0        1910
# 1       1             10           1967          4           170        1977
# 2       1              7            654          4           100        2006
# 3       1              5            968          4             0        1923
# 4       1              6           1394          4             0        1963
#
#    year remod/add  yr sold
# 0            1950     2006
# 1            1977     2006
# 2            2006     2006
# 3            2006     2007
# 4            1963     2009

# %%
print(df['condition 1'].value_counts()),
print(df_test['condition 1'].value_counts())
# Looks like they have the same values
# Out:
# Norm      1767
# Feedr      109
# Artery      70
# RRAn        36
# PosN        27
# RRAe        21
# PosA        12
# RRNn         6
# RRNe         3
# Name: condition 1, dtype: int64
# Norm      755
# Feedr      55
# Artery     22
# RRAn       14
# PosN       11
# PosA        8
# RRAe        7
# RRNn        3
# RRNe        3
# Name: condition 1, dtype: int64

# %%
# Some of these are listed as positive specifically, and normal, but these others dont sounds positive.
# After some googling, it looks like there are definitely positive, negative, normal conditions.  
# It looks like the recomendation is to score them as 2 for postive, 1 for normal, and 0 for negative
# then add the score for each property and use the combined score in the model.

     # 0  Artery	Adjacent to arterial street
     # 0  Feedr	Adjacent to feeder street	
     # 1  Norm	Normal	
     # 0  RRNn	Within 200' of North-South Railroad
     # 0  RRAn	Adjacent to North-South Railroad
     # 2  PosN	Near positive off-site feature--park, greenbelt, etc.
     # 2  PosA	Adjacent to postive off-site feature
     # 0  RRNe	Within 200' of East-West Railroad
     # 0  RRAe	Adjacent to East-West Railroad

# %%
fix_dict_conds = {'Artery':0,
                  'Feedr':0,
                  'Norm':1,
                  'RRNn':0,
                  'RRAn':0,
                  'PosN':2,
                  'PosA':2,
                  'RRNe':0,
                  'RRAe':0   } # create a dictionary of the values in the data and the numeric values you want them to have
df['condition 1'] = df['condition 1'].replace(fix_dict_conds)
df_test['condition 1'] = df_test['condition 1'].replace(fix_dict_conds)
df['condition 2'] = df['condition 2'].replace(fix_dict_conds)
df_test['condition 2'] = df_test['condition 2'].replace(fix_dict_conds)

df['conditions'] = df['condition 1'] + df['condition 2']
df_test['conditions'] = df_test['condition 1'] + df_test['condition 2']

# %%
print(df['conditions'].value_counts())
print(df_test['conditions'].value_counts())
# Out:
# 2    1768
# 1     224
# 3      34
# 0      20
# 4       5
# Name: conditions, dtype: int64
# 2    755
# 1    102
# 3     18
# 0      2
# 4      1
# Name: conditions, dtype: int64

# %%
sns.jointplot(x=df['conditions'],y=df_td['saleprice'],
              kind="reg",
              );

# %%
# The documentation says that the exterior 1 and exterior 2 data are nominal
# but there are some large differences in mean sale price of ext 1

# %%
df.groupby('exterior 1st')['saleprice'].agg(['mean', 'count']).sort_values(by = 'mean')
# Out:
#                      mean  count
# exterior 1st
# AsphShn       82375.00000      1
# CBlock        93250.00000      2
# AsbShng      103183.33333     33
# BrkComm      131000.00000      3
# Stucco       139712.96296     27
# Wd Sdng      142940.88768    276
# MetalSd      154402.04834    331
# WdShing      155616.82222     45
# HdBoard      159582.47333    300
# Plywood      170511.45395    152
# BrkFace      193055.09375     64
# VinylSd      218174.08287    724
# CemntBd      243429.08889     90
# Stone        258500.00000      2
# ImStucc      262000.00000      1

# %%
df.groupby('exterior 2nd')['saleprice'].agg(['mean', 'count']).sort_values(by = 'mean')
# Out:
#                      mean  count
# exterior 2nd
# CBlock        92000.00000      2
# AsbShng      107108.92857     28
# AsphShn      132125.00000      3
# Brk Cmn      139958.82353     17
# Stone        145420.66667      6
# Wd Sdng      145654.39695    262
# Stucco       147725.33333     30
# Wd Shng      154244.44444     63
# MetalSd      155978.63580    324
# HdBoard      160836.88000    275
# Plywood      166485.71351    185
# BrkFace      187992.64706     34
# VinylSd      217798.68516    721
# ImStucc      227472.72727     11
# CmentBd      239540.20000     90

# %%
## some of the values from Ext 1 and Ext 2 dont' quite match on the train data, checking the test data next
print(df['exterior 1st'].unique())
print(df['exterior 2nd'].unique())
print(type(df['exterior 1st'].unique()))

print(list(set(df['exterior 1st']) - set(df['exterior 2nd'])))
print(list(set(df['exterior 2nd']) - set(df['exterior 1st'])))
# Out:
# ['HdBoard' 'VinylSd' 'Wd Sdng' 'BrkFace' 'Plywood' 'MetalSd' 'AsbShng'
#  'CemntBd' 'WdShing' 'Stucco' 'BrkComm' 'Stone' 'CBlock' 'ImStucc'
#  'AsphShn']
# ['Plywood' 'VinylSd' 'Wd Sdng' 'HdBoard' 'MetalSd' 'AsbShng' 'CmentBd'
#  'Wd Shng' 'BrkFace' 'Stucco' 'Brk Cmn' 'ImStucc' 'Stone' 'CBlock'
#  'AsphShn']
# <class 'numpy.ndarray'>
# ['CemntBd', 'BrkComm', 'WdShing']
# ['CmentBd', 'Wd Shng', 'Brk Cmn']

# %%
## alot of mis-match on the test data
print(df_test['exterior 1st'].unique())
print(df_test['exterior 2nd'].unique())


print(list(set(df_test['exterior 1st']) - set(df_test['exterior 2nd'])))
print(list(set(df_test['exterior 2nd']) - set(df_test['exterior 1st'])))
# Out:
# ['AsbShng' 'Plywood' 'VinylSd' 'Wd Sdng' 'CemntBd' 'MetalSd' 'HdBoard'
#  'BrkComm' 'Stucco' 'WdShing' 'BrkFace' 'PreCast' 'AsphShn']
# ['AsbShng' 'Plywood' 'VinylSd' 'Wd Sdng' 'CmentBd' 'MetalSd' 'BrkFace'
#  'Stucco' 'HdBoard' 'Wd Shng' 'ImStucc' 'Brk Cmn' 'PreCast' 'CBlock'
#  'AsphShn' 'Other']
# ['CemntBd', 'BrkComm', 'WdShing']
# ['Wd Shng', 'CBlock', 'CmentBd', 'ImStucc', 'Brk Cmn', 'Other']

# %%
# make Ext 2nd values match those of Ext 1st
fix_dict_ext2 = {'Brk Cmn':'BrkComm',
                  'Wd Shng':'WdShing',
                  'CmentBd':'CemntBd'  } # create a dictionary of the values in the data and the numeric values you want them to have
df['exterior 2nd'] = df['exterior 2nd'].replace(fix_dict_ext2)
df_test['exterior 2nd'] = df_test['exterior 2nd'].replace(fix_dict_ext2)

# %%
# Lets see if the mean sale price of Ext 1 in train  is similar to that of Ext 2

# %%
df.groupby('exterior 1st')['saleprice'].agg(['mean', 'count']).sort_values(by = 'mean')
# Out:
#                      mean  count
# exterior 1st
# AsphShn       82375.00000      1
# CBlock        93250.00000      2
# AsbShng      103183.33333     33
# BrkComm      131000.00000      3
# Stucco       139712.96296     27
# Wd Sdng      142940.88768    276
# MetalSd      154402.04834    331
# WdShing      155616.82222     45
# HdBoard      159582.47333    300
# Plywood      170511.45395    152
# BrkFace      193055.09375     64
# VinylSd      218174.08287    724
# CemntBd      243429.08889     90
# Stone        258500.00000      2
# ImStucc      262000.00000      1

# %%
df.groupby('exterior 2nd')['saleprice'].agg(['mean', 'count']).sort_values(by = 'mean')
# Out:
#                      mean  count
# exterior 2nd
# CBlock        92000.00000      2
# AsbShng      107108.92857     28
# AsphShn      132125.00000      3
# BrkComm      139958.82353     17
# Stone        145420.66667      6
# Wd Sdng      145654.39695    262
# Stucco       147725.33333     30
# WdShing      154244.44444     63
# MetalSd      155978.63580    324
# HdBoard      160836.88000    275
# Plywood      166485.71351    185
# BrkFace      187992.64706     34
# VinylSd      217798.68516    721
# ImStucc      227472.72727     11
# CemntBd      239540.20000     90

# %%
# the mean sale price of Ext 1 and Ext 2 are similar but there are a few big differences.  
# I'm going to assign each it's own Ordinal value, then, similar to what we did with 
# conditions, combine the two columns

# %%
    #    AsbShng	Asbestos Shingles
    #    AsphShn	Asphalt Shingles
    #    BrkComm	Brick Common
    #    BrkFace	Brick Face
    #    CBlock	Cinder Block
    #    CemntBd	Cement Board
    #    HdBoard	Hard Board
    #    ImStucc	Imitation Stucco
    #    MetalSd	Metal Siding
    #    Other	Other
    #    Plywood	Plywood
    #    PreCast	PreCast	
    #    Stone	Stone
    #    Stucco	Stucco
    #    VinylSd	Vinyl Siding
    #    Wd Sdng	Wood Siding
    #    WdShing	Wood Shingles

# %%
fix_dict_ext1 = {
    'AsphShn':1,
    'CBlock':2,
    'AsbShng':3,
    'BrkComm':4,
    'Stucco':5,
    'Wd Sdng':6,
    'MetalSd':7,
    'PreCast':8,
    'WdShing':9,
    'HdBoard':10,
    'Plywood':11,
    'BrkFace':12,
    'VinylSd':13,
    'CemntBd':14,
    'Stone':15,
    'ImStucc':16  } # create a dictionary of the values in the data and the numeric values you want them to have
df['exterior 1st'] = df['exterior 1st'].replace(fix_dict_ext1)
df_test['exterior 1st'] = df_test['exterior 1st'].replace(fix_dict_ext1)

# %%
print(df_test['exterior 1st'].unique())
print(df_test['exterior 1st'].value_counts())
# Not sure what to do about PreCast, maybe just assume the mean sale price? stick it in the middle?
df['saleprice'].mean()
# Out:
# [ 3 11 13  6 14  7 10  4  5  9 12  8  1]
# 13    302
# 6     144
# 10    142
# 7     119
# 11     69
# 14     35
# 12     24
# 5      16
# 3      11
# 9      11
# 4       3
# 8       1
# 1       1
# Name: exterior 1st, dtype: int64
# 181469.70160897123

# %%
fix_dict_ext2 = {
    'Other':0,
    'CBlock':1,
    'AsbShng':2,
    'AsphShn':3,
    'BrkComm':4,
    'Stone':5,
    'Wd Sdng':6,
    'Stucco':7,
    'PreCast':8,
    'WdShing':9,
    'MetalSd':10,
    'HdBoard':11,
    'Plywood':12,
    'BrkFace':13,
    'VinylSd':14,
    'ImStucc':15,
    'CemntBd':16} # create a dictionary of the values in the data and the numeric values you want them to have


df['exterior 2nd'] = df['exterior 2nd'].replace(fix_dict_ext2)
df_test['exterior 2nd'] = df_test['exterior 2nd'].replace(fix_dict_ext2)

# %%
print(df_test['exterior 2nd'].unique())
print(df_test['exterior 2nd'].value_counts())
# Not sure what to do about PreCast, maybe just assume the mean sale price? stick it in the middle?
# Out:
# [ 2 12 14  6 16 10 13  7 11  9 15  4  8  1  3  0]
# 14    294
# 6     135
# 11    131
# 10    123
# 12     89
# 16     35
# 9      18
# 7      17
# 13     13
# 2      10
# 4       5
# 15      4
# 8       1
# 1       1
# 3       1
# 0       1
# Name: exterior 2nd, dtype: int64

# %%
df['exterior 2nd'] = df['exterior 2nd'].replace(fix_dict_ext2)
df_test['exterior 2nd'] = df_test['exterior 2nd'].replace(fix_dict_ext2)

df['exteriors'] = df['exterior 1st'] + df['exterior 2nd']
df_test['exteriors'] = df_test['exterior 1st'] + df_test['exterior 2nd']

# %%
print(df['foundation'].value_counts())
# Out:
# PConc     926
# CBlock    863
# BrkTil    221
# Slab       34
# Stone       5
# Wood        2
# Name: foundation, dtype: int64

# %%
print(df_test['foundation'].value_counts())
# Out:
# PConc     383
# CBlock    381
# BrkTil     90
# Slab       15
# Stone       6
# Wood        3
# Name: foundation, dtype: int64

# %%
df.groupby('foundation')['saleprice'].agg(['mean', 'count','min','max']).sort_values(by = 'mean')  
# Think I'll just created dummies for these
# Out:
#                    mean  count     min     max
# foundation
# Slab       108810.67647     34   13100  284700
# BrkTil     129050.19005    221   12789  475000
# Stone      143235.20000      5   89000  266500
# CBlock     148415.53071    863   34900  410000
# Wood       173750.00000      2  145500  202000
# PConc      227676.48380    926   63000  611657

# %%
df_test.head()
# Out:
#    1st flr sf  2nd flr sf  3ssn porch  alley  bedroom abvgr bldg type  \
# 0         908        1020           0      2              4    2fmCon
# 1        1967           0           0      0              6    Duplex
# 2         664         832           0      0              3      1Fam
# 3         968           0           0      0              2      1Fam
# 4        1394           0           0      0              3      1Fam
#
#    bsmt cond  bsmt exposure  bsmt full bath  bsmt half bath  bsmt qual  \
# 0          3              1               0               0          2
# 1          3              1               0               0          4
# 2          4              3               1               0          4
# 3          3              1               0               0          3
# 4          3              1               1               0          4
#
#    bsmt unf sf  bsmtfin sf 1  bsmtfin sf 2 bsmtfin type 1 bsmtfin type 2  \
# 0         1020             0             0              1              1
# 1         1967             0             0              1              1
# 2          100           554             0              6              1
# 3          968             0             0              1              1
# 4          785           609             0              4              1
#
#    central air  condition 1  condition 2  electrical  enclosed porch  \
# 0            0            1            1           2             112
# 1            1            1            1           5               0
# 2            1            1            1           5               0
# 3            1            1            1           5             184
# 4            1            1            1           5               0
#
#    exter cond  exter qual  exterior 1st  exterior 2nd  fence  fireplace qu  \
# 0           2           3             3             2      0             0
# 1           3           3            11            12      0             0
# 2           3           4            13            14      0             4
# 3           3           4             6             6      0             0
# 4           3           3            11            12      0             4
#
#    fireplaces foundation  full bath  functional  garage area  garage cars  \
# 0           0      Stone          2           8          440            1
# 1           0     CBlock          2           8          580            2
# 2           1      PConc          2           8          426            2
# 3           0     CBlock          1           8          480            2
# 4           2     CBlock          1           8          514            2
#
#    garage cond  garage finish  garage qual garage type garage yr blt  \
# 0            1              1            1      Detchd    1910.00000
# 1            3              3            3      Attchd    1977.00000
# 2            3              2            3      Attchd    2006.00000
# 3            3              1            2      Detchd    1935.00000
# 4            3              2            3      Attchd    1963.00000
#
#    gr liv area  half bath heating  heating qc house style    id  \
# 0         1928          0    GasA           4      2Story  2658
# 1         1967          0    GasA           3      1Story  2718
# 2         1496          1    GasA           5      2Story  2414
# 3          968          0    GasA           3      1Story  1989
# 4         1394          1    GasA           4      1Story   625
#
#    kitchen abvgr  kitchen qual land contour  land slope  lot area lot config  \
# 0              2             2          Lvl           3      9142     Inside
# 1              2             3          Lvl           3      9662     Inside
# 2              1             4          Lvl           3     17104     Inside
# 3              1             3          Lvl           3      8520     Inside
# 4              1             3          Lvl           3      9500     Inside
#
#    lot frontage  lot shape  low qual fin sf  ms subclass ms zoning  \
# 0      69.00000          4                0          190        RM
# 1      67.49638          3                0           90        RL
# 2      58.00000          3                0           60        RL
# 3      60.00000          4                0           30        RM
# 4      67.49638          3                0           20        RL
#
#    mas vnr area mas vnr type misc feature  misc val  mo sold neighborhood  \
# 0       0.00000         None           NA         0        4      OldTown
# 1       0.00000         None           NA         0        8       Sawyer
# 2       0.00000         None           NA         0        9      Gilbert
# 3       0.00000         None           NA         0        7      OldTown
# 4     247.00000      BrkFace           NA         0        7        NAmes
#
#    open porch sf  overall cond  overall qual        pid  paved drive  \
# 0             60             8             6  902301120            2
# 1              0             4             5  905108090            2
# 2             24             5             7  528218130            2
# 3              0             6             5  902207150            0
# 4             76             5             6  535105100            2
#
#    pool area  pool qc roof matl roof style sale type  saleprice  screen porch  \
# 0          0        0   CompShg      Gable       WD         NaN             0
# 1          0        0   CompShg      Gable       WD         NaN             0
# 2          0        0   CompShg      Gable       New        NaN             0
# 3          0        0   CompShg      Gable       WD         NaN             0
# 4          0        0   CompShg      Gable       WD         NaN           185
#
#    street  totrms abvgrd  total bsmt sf  utilities  wood deck sf  year built  \
# 0       1              9           1020          4             0        1910
# 1       1             10           1967          4           170        1977
# 2       1              7            654          4           100        2006
# 3       1              5            968          4             0        1923
# 4       1              6           1394          4             0        1963
#
#    year remod/add  yr sold  conditions  exteriors
# 0            1950     2006           2          5
# 1            1977     2006           2         23
# 2            2006     2006           2         27
# 3            2006     2007           2         12
# 4            1963     2009           2         23

# %%
print(df['garage type'].value_counts())
# Out:
# Attchd     1213
# Detchd      536
# BuiltIn     132
# NA          113
# Basment      27
# 2Types       19
# CarPort      11
# Name: garage type, dtype: int64

# %%
print(df_test['garage type'].value_counts())
# Out:
# Attchd     518
# Detchd     246
# BuiltIn     53
# NA          44
# Basment      9
# 2Types       4
# CarPort      4
# Name: garage type, dtype: int64

# %%
df.groupby('garage type')['saleprice'].agg(['mean', 'count','min','max']).sort_values(by = 'mean')  
# not surprised that carport is on the low end of the mean, followed by detached
# not surprised the Attached and BuiltIn are on the higher end
# but I am surprised by the large ranges in min/mx
# Think I'll create dummies for these
# Out:
#                     mean  count    min     max
# garage type
# CarPort     103823.54545     11  82000  148000
# NA          105669.15044    113  34900  200500
# Detchd      132132.94776    536  12789  475000
# Basment     143242.33333     27  55993  235000
# 2Types      157184.21053     19  87000  235000
# Attchd      205040.19538   1213  13100  611657
# BuiltIn     247883.52273    132  91000  582933

# %%
print(df['heating'].value_counts())
# Out:
# GasA    2018
# GasW      20
# Wall       6
# Grav       5
# OthW       2
# Name: heating, dtype: int64

# %%
print(df_test['heating'].value_counts())
# Out:
# GasA     866
# GasW       7
# Grav       4
# Floor      1
# Name: heating, dtype: int64

# %%
df.groupby('heating')['saleprice'].agg(['mean', 'count','min','max']).sort_values(by = 'mean')
# Out:
#                 mean  count     min     max
# heating
# Grav     65180.00000      5   37900   80000
# Wall     77150.00000      6   13100   98000
# OthW    125750.00000      2  122000  129500
# GasW    151275.00000     20   85000  256000
# GasA    182422.47671   2018   12789  611657

# %%
# Gravity and Wall furnaces definitely seem to be on the low end
# OthW has a narrow band in the middle
# GasW and GasA have much wider bands, though
# Im not sure that there is any correlation to sales price

#Going to create dummies

# %%
print(df['house style'].value_counts())
# Out:
# 1Story    1059
# 2Story     598
# 1.5Fin     218
# SLvl        94
# SFoyer      50
# 2.5Unf      14
# 1.5Unf      12
# 2.5Fin       6
# Name: house style, dtype: int64

# %%
print(df_test['house style'].value_counts())
# Out:
# 1Story    422
# 2Story    274
# 1.5Fin     96
# SLvl       34
# SFoyer     33
# 2.5Unf     10
# 1.5Unf      7
# 2.5Fin      2
# Name: house style, dtype: int64

# %%
df.groupby('house style')['saleprice'].agg(['mean', 'count','min','max']).sort_values(by = 'mean')
# Out:
#                     mean  count     min     max
# house style
# 1.5Unf      112466.66667     12   64500  139400
# 1.5Fin      136480.09174    218   37900  410000
# SFoyer      149343.92000     50   73000  224500
# SLvl        166248.98936     94   91000  345000
# 1Story      179809.19452   1059   12789  611657
# 2.5Unf      191785.71429     14  101000  415000
# 2Story      206408.96321    598   40000  584500
# 2.5Fin      243666.66667      6  104000  475000

# %%
df=pd.get_dummies(df, columns=['alley'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['alley'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['bldg type'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['bldg type'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['foundation'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['foundation'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['garage type'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['garage type'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['heating'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['heating'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['house style'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['house style'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['land contour'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['land contour'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['lot config'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['lot config'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['ms zoning'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['ms zoning'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['mas vnr type'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['mas vnr type'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['misc feature'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['misc feature'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['neighborhood'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['neighborhood'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['roof matl'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['roof matl'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['roof style'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['roof style'], drop_first=False)

# %%
df=pd.get_dummies(df, columns=['sale type'], drop_first=False)
df_test=pd.get_dummies(df_test, columns=['sale type'], drop_first=False)

# %%
print('Finished')
# Out:
# Finished

# %%
################################################################################

# %%
################################################################################

# %%
df.columns = df.columns.str.lower() # column names to lower case
df_test.columns = df_test.columns.str.lower() # column names to lower case

# %%
df.to_csv('./datasets/cleaned_train2.csv', index=False)

# %%
df_test.to_csv('./datasets/cleaned_test2.csv', index=False)
